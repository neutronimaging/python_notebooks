# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorial/notebooks/timepix3_raw_to_profile_of_roi)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select your IPTS

# %%
from __code import system
from __code.timepix3_raw_to_profile_of_roi.main import Timepix3RawToProfileOfRoi

system.System.select_working_dir(facility='SNS', instrument='VENUS', instrument_to_exclude=["SNAP", "MARS"])
from __code.__all import custom_style
custom_style.style()

import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ...

# %% [markdown]
# # Select the tpx3 data file

# %%
o_tpx3 = Timepix3RawToProfileOfRoi(working_dir=system.System.get_working_dir(), debug=True)
o_tpx3.select_tpx3()
# Out:
# log file: /SNS/users/j35/logs/timepix3_raw_to_profile_of_roi.log
