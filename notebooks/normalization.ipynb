# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/normalization/manual-normalization/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code.normalization.normalization import Normalization

from __code import system
system.System.select_working_dir(notebook='normalization', instrument="CG1D", ipts="IPTS-36100")
from __code.__all import custom_style
custom_style.style()

Normalization.legend()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ...
# <hr style='height:2px'/>
# <h2>Legend</h2>
# <ul><li><b><font color='red'>Mandatory steps</font></b> must be performed to ensure proper data processing.</li><li><b><font color='orange'>Optional but recommended steps</font></b> are not mandatory but should be performed to ensure proper data processing.</li><li><b><font color='purple'>Optional steps</font></b> are not mandatory but highly recommended to improve the quality of your data processing.</li></ul>
# <hr style='height:2px'/>

# %% [markdown]
# # <font color='red'>Select sample runs</font>

# %%
o_norm = Normalization(working_dir=system.System.get_working_dir())
o_norm.select_sample_runs()
# Out:
# ...
# <span style='font-size:16px; color:blue'>3 Sample files selected</span>

# %% [markdown]
# # <font color='red'>Select open beam (ob) images</font>

# %%
o_norm.select_ob_runs()
# Out:
# ...
# <span style='font-size:16px; color:blue'>4 OB files selected</span>

# %% [markdown]
# # <font color='purple'>Select dark current (dc) images</font><font color='purple' size='3'> - OPTIONAL</font>

# %%
o_norm.select_dc_runs()

# %% [markdown]
# # <font color='purple'>Select background region</font><font color='purple' size='3'> - OPTIONAL</font>
#
# This may improves the normalization by selecting a <b>background</b> region in your sample images. Make sure you don't select any part of the sample

# %%
# %gui qt

# %%
o_norm.select_background_region()

# %% [markdown]
# # <font color='red'>Normalization</font>
#
# ### <font color='red'>Define the normalization settings</font>

# %%
o_norm.normalization_settings()
# Out:
# ...
# Loading ob:   0%|          | 0/4 [00:00<?, ?it/s]
# Accordion(children=(RadioButtons(layout=Layout(width='200px'), options=('median', 'mean'), value='median'), HT…

# %% [markdown]
# ### <font color='red'>Select output folder</font>

# %%
o_norm.select_output_folder()
# Out:
# ...
# <span style='font-size:16px; color:blue'>Output folder selected: /HFIR/CG1D/IPTS-36100/shared/processed_data/jean_test</span>

# %% [markdown]
# ### <font color='red'>Perform normalization</font>

# %%
o_norm.export_normalized_data()
# Out:
# ...
# IntProgress(value=0, description='Exporting: ', max=3)
# <span style="font-size: 20px; color:blue">The normalized images have been created in /HFIR/CG1D/IPTS-36100/shared/processed_data/jean_test/2025_09_25_POS_EL_2_normalized</span>
