# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/normalization/manual-normalization/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code.normalization.normalization import *
from __code.roi_selection_ui import Interface

from __code import system
system.System.select_working_dir(notebook='normalization')
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# ** Using Debugging Mode! **
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %% [markdown]
# # Python Import

# %%
# %gui qt

# %% [markdown]
# # Select Images: Sample, open beam (OB) , and dark current (DC)

# %%
files = Files()
sample_panel = SampleSelectionPanel(working_dir=system.System.get_working_dir())
sample_panel.init_ui(files=files)
wizard = WizardPanel(sample_panel=sample_panel)
# Out:
# Label(value='Selection of All Input Files', layout=Layout(border_bottom='1px lighgray solide', border_left='1p…
# VBox(children=(HBox(children=(Label(value='Instructions:', layout=Layout(width='20%')), Label(value='Select li…
# HBox(children=(Label(value='         ', layout=Layout(width='70%')), Button(button_style='warning', descriptio…
# VBox(children=(HTML(value="<b><font color='green'></b>"), VBox(children=(HBox(children=(HBox(children=(Text(va…
# VBox(children=(HBox(children=(Label(value='Instructions:', layout=Layout(width='20%')), Label(value='Select li…
# HBox(children=(Button(button_style='success', description='<< Previous Step', layout=Layout(width='20%'), styl…
# VBox(children=(HTML(value="<b><font color='green'></b>"), VBox(children=(HBox(children=(HBox(children=(Text(va…
# VBox(children=(HBox(children=(Label(value='Instructions:', layout=Layout(width='20%')), Label(value='Select li…
# HBox(children=(Button(button_style='success', description='<< Previous Step', layout=Layout(width='20%'), styl…
# VBox(children=(HTML(value="<b><font color='green'></b>"), VBox(children=(HBox(children=(HBox(children=(Text(va…
# Loading sample:   0%|          | 0/2160 [00:00<?, ?it/s]
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# ...
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# WARNING:root:Use default max value for data type: Invalid integer data type 'f'.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/git/python_notebooks/notebooks/__code/normalization/normalization.py:280, in DFSelectionPanel.next_button_clicked(self, event)
#     276 self.remove()
#     277 o_norm_handler = NormalizationHandler(files=self.files,
#     278                                       working_dir=self.working_dir,
#     279                                       gamma_threshold=self.gamma_threshold)
# --> 280 o_norm_handler.load_data()
#     281 self.top_object.o_norm_handler = o_norm_handler
#     282 self.top_object.o_norm = o_norm_handler.o_norm
#
# File ~/git/python_notebooks/notebooks/__code/normalization/normalization.py:307, in NormalizationHandler.load_data(self)
#     304 list_sample = self.files.sample
#     305 # self.o_norm.load(file=list_sample, notebook=True, auto_gamma_filter=False,
#     306 #                  manual_gamma_filter=True, manual_gamma_threshold=self.gamma_threshold)
# --> 307 self.o_norm.load(file=list_sample, notebook=True)
#     308 self.data.sample = self.o_norm.data['sample']['data']
#     309 self.list_file_names = list_sample
#
# File ~/opt/anaconda3/envs/python310_notebook7/lib/python3.10/site-packages/NeuNorm/normalization.py:120, in Normalization.load(self, file, folder, data, data_type, auto_gamma_filter, manual_gamma_filter, notebook, manual_gamma_threshold, check_shape)
#     117     elif isinstance(file, list):
#     118         # use tqdm to handle the progress bar
#     119         for _file in tqdm(file, desc=f"Loading {data_type}", leave=False):
# --> 120             self.load_file(
#     121                 file=_file,
#     122                 data_type=data_type,
#     123                 auto_gamma_filter=auto_gamma_filter,
#     124                 manual_gamma_filter=manual_gamma_filter,
#     125                 manual_gamma_threshold=manual_gamma_threshold,
#     126                 check_shape=check_shape,
#     127             )
#     129 elif not folder == "":
#     130     # load all files from folder
#     131     list_images = get_sorted_list_images(folder=folder)
#
# File ~/opt/anaconda3/envs/python310_notebook7/lib/python3.10/site-packages/NeuNorm/normalization.py:257, in Normalization.load_file(self, file, data_type, auto_gamma_filter, manual_gamma_filter, manual_gamma_threshold, check_shape)
#     254     raise NotImplementedError
#     255 #     data = np.array(load_hdf(my_file))
#     256 else:
# --> 257     raise OSError(
#     258         "file extension not yet implemented....Do it your own way!"
#     259     )
#     261 if auto_gamma_filter:
#     262     data = self._auto_gamma_filtering(data=data)
#
# OSError: file extension not yet implemented....Do it your own way!

# %% [markdown]
# # Select Background Region

# %%
o_norm = sample_panel.o_norm_handler
o_gui = Interface(o_norm=o_norm.o_norm)
o_gui.show()

# %% [markdown]
# # Normalization

# %% [markdown]
# ## Settings

# %%
o_norm.settings()

# %% [markdown]
# ## Create normalized data

# %%
o_norm.run_normalization(dict_roi=o_gui.roi_selected)

# %% [markdown]
# # Export

# %%
o_norm.select_export_folder(ipts_folder=sample_panel.ipts_dir)

# %%
o_norm.export()
