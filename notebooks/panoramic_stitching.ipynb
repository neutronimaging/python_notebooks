# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.pages.ornl.gov/tutorial/notebooks/panoramic_stitching/#activate-search)
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code.panoramic_stitching.panoramic_stitching import PanoramicStitching
from __code import system
system.System.select_working_dir()
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ** Using Debugging Mode! **
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %% [markdown]
# # Select Input Folder(s)
#
# Select all the folders containing the images to stitch. Ideally, those folders have been created by the notebook [group_images_by_cycle_for_panoramic_stitching](group_images_by_cycle_for_panoramic_stitching.ipynb)

# %%
o_stitch = PanoramicStitching(working_dir=system.System.get_working_dir())
o_stitch.select_input_folders()
# Out:
# VBox(children=(Label(value='select all the folders of images to stitch', layout=Layout(width='250px')), VBox(c…
# <span style="font-size: 15px; color:blue">Notebook is about to work with 6 folders!</span><span style="font-size: 15px; color:green"></span>

# %% [markdown]
# # DEBUGGING

# %%
import glob
from __code.panoramic_stitching.panoramic_stitching import PanoramicStitching, Interface
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# Warning: QApplication was created before pyqtgraph was imported; there may be problems (to avoid bugs, call QApplication.setGraphicsSystem("raster") before the QApplication is created).

# %%
# %gui qt

# %%
list_folder_selected = glob.glob("/Users/j35/IPTS/IPTS-20267-Jonathan/Jan07_2020_sorted_by_cycle/group#0*")
list_folder_selected.sort()

o_interface = Interface(list_folders=list_folder_selected)
o_interface.show()
o_interface.load_data()
o_interface.initialization_after_loading_data()
# Out:
# <span style="font-size: 15px; color:blue">Check UI that popped up                     (maybe hidden behind this browser!)</span><span style="font-size: 15px; color:green"></span>
# //miniconda3/envs/py36/lib/python3.6/site-packages/pyqtgraph/imageview/ImageView.py:588: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data = data[sl]
# x:500.0 and y:200.0
# width:2000.0 and height:8.0
# x:500.0 and y:200.0
# width:2000.0 and height:8.0
# x:500.0 and y:200.0
# width:2000.0 and height:10.0
# x:500.0 and y:200.0
# width:2000.0 and height:10.0
# x:500.0 and y:200.0
# width:2000.0 and height:11.0
# x:500.0 and y:200.0
# width:2000.0 and height:11.0
# x:500.0 and y:200.0
# width:2000.0 and height:13.0
# x:500.0 and y:200.0
# width:2000.0 and height:13.0
# x:500.0 and y:200.0
# width:2000.0 and height:14.0
# x:500.0 and y:200.0
# width:2000.0 and height:14.0
# x:500.0 and y:200.0
# width:2000.0 and height:15.0
# x:500.0 and y:200.0
# width:2000.0 and height:15.0
# x:500.0 and y:200.0
# width:2000.0 and height:17.0
# x:500.0 and y:200.0
# width:2000.0 and height:17.0
# x:500.0 and y:200.0
# width:2000.0 and height:18.0
# x:500.0 and y:200.0
# width:2000.0 and height:18.0
# x:500.0 and y:200.0
# width:2000.0 and height:20.0
# x:500.0 and y:200.0
# width:2000.0 and height:20.0
# x:500.0 and y:200.0
# width:2000.0 and height:21.0
# x:500.0 and y:200.0
# width:2000.0 and height:21.0
# x:500.0 and y:200.0
# width:2000.0 and height:23.0
# x:500.0 and y:200.0
# width:2000.0 and height:23.0
# x:500.0 and y:200.0
# width:2000.0 and height:24.0
# x:500.0 and y:200.0
# width:2000.0 and height:24.0
# x:500.0 and y:200.0
# width:2000.0 and height:25.0
# x:500.0 and y:200.0
# width:2000.0 and height:25.0
# x:500.0 and y:200.0
# width:2000.0 and height:27.0
# x:500.0 and y:200.0
# width:2000.0 and height:27.0
# x:500.0 and y:200.0
# width:2000.0 and height:28.0
# x:500.0 and y:200.0
# width:2000.0 and height:28.0
# x:500.0 and y:200.0
# width:2000.0 and height:30.0
# x:500.0 and y:200.0
# width:2000.0 and height:30.0
# x:500.0 and y:200.0
# width:2000.0 and height:31.0
# x:500.0 and y:200.0
# width:2000.0 and height:31.0
# x:500.0 and y:200.0
# width:2000.0 and height:33.0
# x:500.0 and y:200.0
# width:2000.0 and height:33.0
# x:500.0 and y:200.0
# width:2000.0 and height:34.0
# x:500.0 and y:200.0
# width:2000.0 and height:34.0
# x:500.0 and y:200.0
# width:2000.0 and height:36.0
# x:500.0 and y:200.0
# width:2000.0 and height:36.0
# x:500.0 and y:200.0
# width:2000.0 and height:37.0
# x:500.0 and y:200.0
# width:2000.0 and height:37.0
# x:500.0 and y:200.0
# width:2000.0 and height:38.0
# x:500.0 and y:200.0
# width:2000.0 and height:38.0
# x:500.0 and y:200.0
# width:2000.0 and height:40.0
# x:500.0 and y:200.0
# width:2000.0 and height:40.0
# x:500.0 and y:200.0
# width:2000.0 and height:41.0
# x:500.0 and y:200.0
# width:2000.0 and height:41.0
# x:500.0 and y:200.0
# width:2000.0 and height:43.0
# x:500.0 and y:200.0
# width:2000.0 and height:43.0
# x:500.0 and y:200.0
# width:2000.0 and height:44.0
# x:500.0 and y:200.0
# width:2000.0 and height:44.0
# x:500.0 and y:200.0
# width:2000.0 and height:46.0
# x:500.0 and y:200.0
# width:2000.0 and height:46.0
# x:500.0 and y:200.0
# width:2000.0 and height:47.0
# x:500.0 and y:200.0
# width:2000.0 and height:47.0
# x:500.0 and y:200.0
# width:2000.0 and height:48.0
# x:500.0 and y:200.0
# width:2000.0 and height:48.0
# x:500.0 and y:200.0
# width:2000.0 and height:50.0
# x:500.0 and y:200.0
# width:2000.0 and height:50.0
# x:500.0 and y:200.0
# width:2000.0 and height:51.0
# x:500.0 and y:200.0
# width:2000.0 and height:51.0
# x:500.0 and y:200.0
# width:2000.0 and height:53.0
# x:500.0 and y:200.0
# width:2000.0 and height:53.0
# x:500.0 and y:200.0
# width:2000.0 and height:54.0
# x:500.0 and y:200.0
# width:2000.0 and height:54.0
# x:500.0 and y:200.0
# width:2000.0 and height:56.0
# x:500.0 and y:200.0
# width:2000.0 and height:56.0
# x:500.0 and y:200.0
# width:2000.0 and height:57.0
# x:500.0 and y:200.0
# width:2000.0 and height:57.0
# x:500.0 and y:200.0
# width:2000.0 and height:59.0
# x:500.0 and y:200.0
# width:2000.0 and height:59.0
# x:500.0 and y:200.0
# width:2000.0 and height:60.0
# x:500.0 and y:200.0
# width:2000.0 and height:60.0
# x:500.0 and y:200.0
# width:2000.0 and height:61.0
# x:500.0 and y:200.0
# width:2000.0 and height:61.0
# x:500.0 and y:200.0
# width:2000.0 and height:63.0
# x:500.0 and y:200.0
# width:2000.0 and height:63.0
# x:500.0 and y:200.0
# width:2000.0 and height:64.0
# x:500.0 and y:200.0
# width:2000.0 and height:64.0
# x:500.0 and y:200.0
# width:2000.0 and height:66.0
# x:500.0 and y:200.0
# width:2000.0 and height:66.0
# x:500.0 and y:200.0
# width:2000.0 and height:67.0
# x:500.0 and y:200.0
# width:2000.0 and height:67.0
# x:500.0 and y:200.0
# width:2000.0 and height:69.0
# x:500.0 and y:200.0
# width:2000.0 and height:69.0
# x:500.0 and y:200.0
# width:2000.0 and height:70.0
# x:500.0 and y:200.0
# width:2000.0 and height:70.0
# x:500.0 and y:200.0
# width:2000.0 and height:71.0
# x:500.0 and y:200.0
# width:2000.0 and height:71.0
# x:500.0 and y:200.0
# width:2000.0 and height:73.0
# x:500.0 and y:200.0
# width:2000.0 and height:73.0
# x:500.0 and y:200.0
# width:2000.0 and height:74.0
# x:500.0 and y:200.0
# width:2000.0 and height:74.0
# x:500.0 and y:200.0
# width:2000.0 and height:76.0
# x:500.0 and y:200.0
# width:2000.0 and height:76.0
# x:500.0 and y:200.0
# width:2000.0 and height:79.0
# x:500.0 and y:200.0
# width:2000.0 and height:79.0
# x:500.0 and y:200.0
# width:2000.0 and height:80.0
# x:500.0 and y:200.0
# width:2000.0 and height:80.0
# x:500.0 and y:200.0
# width:2000.0 and height:82.0
# x:500.0 and y:200.0
# width:2000.0 and height:82.0
# x:500.0 and y:200.0
# width:2000.0 and height:84.0
# x:500.0 and y:200.0
# width:2000.0 and height:84.0
# x:500.0 and y:200.0
# width:2000.0 and height:86.0
# x:500.0 and y:200.0
# width:2000.0 and height:86.0
# x:500.0 and y:200.0
# width:2000.0 and height:87.0
# x:500.0 and y:200.0
# width:2000.0 and height:87.0
# x:500.0 and y:200.0
# width:2000.0 and height:89.0
# x:500.0 and y:200.0
# width:2000.0 and height:89.0
# x:500.0 and y:200.0
# width:2000.0 and height:87.0
# x:500.0 and y:200.0
# width:2000.0 and height:87.0
# x:500.0 and y:200.0
# width:2000.0 and height:86.0
# x:500.0 and y:200.0
# width:2000.0 and height:86.0
# x:500.0 and y:200.0
# width:2000.0 and height:84.0
# x:500.0 and y:200.0
# width:2000.0 and height:84.0
# x:500.0 and y:200.0
# width:2000.0 and height:83.0
# x:500.0 and y:200.0
# width:2000.0 and height:83.0
# x:500.0 and y:200.0
# width:2000.0 and height:82.0
# x:500.0 and y:200.0
# width:2000.0 and height:82.0
# x:500.0 and y:200.0
# width:2000.0 and height:80.0
# x:500.0 and y:200.0
# width:2000.0 and height:80.0
# x:500.0 and y:200.0
# width:2000.0 and height:79.0
# x:500.0 and y:200.0
# width:2000.0 and height:79.0
# x:500.0 and y:200.0
# width:2000.0 and height:77.0
# x:500.0 and y:200.0
# width:2000.0 and height:77.0
# x:500.0 and y:200.0
# width:2000.0 and height:76.0
# x:500.0 and y:200.0
# width:2000.0 and height:76.0
# x:500.0 and y:200.0
# width:2000.0 and height:74.0
# x:500.0 and y:200.0
# width:2000.0 and height:74.0
# x:500.0 and y:200.0
# width:2000.0 and height:73.0
# x:500.0 and y:200.0
# width:2000.0 and height:73.0
# x:500.0 and y:200.0
# width:2000.0 and height:71.0
# x:500.0 and y:200.0
# width:2000.0 and height:71.0
# x:500.0 and y:200.0
# width:2000.0 and height:70.0
# x:500.0 and y:200.0
# width:2000.0 and height:70.0
# x:500.0 and y:200.0
# width:2000.0 and height:69.0
# x:500.0 and y:200.0
# width:2000.0 and height:69.0
# x:500.0 and y:200.0
# width:2000.0 and height:67.0
# x:500.0 and y:200.0
# width:2000.0 and height:67.0
# x:500.0 and y:200.0
# width:2000.0 and height:66.0
# x:500.0 and y:200.0
# width:2000.0 and height:66.0
# x:500.0 and y:200.0
# width:2000.0 and height:64.0
# x:500.0 and y:200.0
# width:2000.0 and height:64.0
# x:500.0 and y:200.0
# width:2000.0 and height:63.0
# x:500.0 and y:200.0
# width:2000.0 and height:63.0
# x:500.0 and y:200.0
# width:2000.0 and height:61.0
# x:500.0 and y:200.0
# width:2000.0 and height:61.0
# x:500.0 and y:200.0
# width:2000.0 and height:60.0
# x:500.0 and y:200.0
# width:2000.0 and height:60.0
# x:500.0 and y:200.0
# width:2000.0 and height:59.0
# x:500.0 and y:200.0
# width:2000.0 and height:59.0
# x:500.0 and y:200.0
# width:2000.0 and height:57.0
# x:500.0 and y:200.0
# width:2000.0 and height:57.0
# x:500.0 and y:200.0
# width:2000.0 and height:56.0
# x:500.0 and y:200.0
# width:2000.0 and height:56.0
# x:500.0 and y:200.0
# width:2000.0 and height:54.0
# x:500.0 and y:200.0
# width:2000.0 and height:54.0
# x:500.0 and y:200.0
# width:2000.0 and height:53.0
# x:500.0 and y:200.0
# width:2000.0 and height:53.0
# x:500.0 and y:200.0
# width:2000.0 and height:50.0
# x:500.0 and y:200.0
# width:2000.0 and height:50.0
# x:500.0 and y:200.0
# width:2000.0 and height:48.0
# x:500.0 and y:200.0
# width:2000.0 and height:48.0
# x:500.0 and y:200.0
# width:2000.0 and height:46.0
# x:500.0 and y:200.0
# width:2000.0 and height:46.0
# x:500.0 and y:200.0
# width:2000.0 and height:43.0
# x:500.0 and y:200.0
# width:2000.0 and height:43.0
# x:500.0 and y:200.0
# width:2000.0 and height:41.0
# x:500.0 and y:200.0
# width:2000.0 and height:41.0
# x:500.0 and y:200.0
# width:2000.0 and height:40.0
# x:500.0 and y:200.0
# width:2000.0 and height:40.0
# x:500.0 and y:200.0
# width:2000.0 and height:38.0
# x:500.0 and y:200.0
# width:2000.0 and height:38.0
# x:500.0 and y:200.0
# width:2000.0 and height:37.0
# x:500.0 and y:200.0
# width:2000.0 and height:37.0
# x:500.0 and y:200.0
# width:2000.0 and height:36.0
# x:500.0 and y:200.0
# width:2000.0 and height:36.0
# x:500.0 and y:200.0
# width:2000.0 and height:34.0
# x:500.0 and y:200.0
# width:2000.0 and height:34.0
# x:500.0 and y:200.0
# width:2000.0 and height:33.0
# x:500.0 and y:200.0
# width:2000.0 and height:33.0
# x:500.0 and y:200.0
# width:2000.0 and height:31.0
# x:500.0 and y:200.0
# width:2000.0 and height:31.0
# x:500.0 and y:200.0
# width:2000.0 and height:30.0
# x:500.0 and y:200.0
# width:2000.0 and height:30.0
# x:500.0 and y:200.0
# width:2000.0 and height:27.0
# x:500.0 and y:200.0
# width:2000.0 and height:27.0
# x:500.0 and y:200.0
# width:2000.0 and height:25.0
# x:500.0 and y:200.0
# width:2000.0 and height:25.0
# x:500.0 and y:200.0
# width:2000.0 and height:24.0
# x:500.0 and y:200.0
# width:2000.0 and height:24.0
# x:500.0 and y:200.0
# width:2000.0 and height:23.0
# x:500.0 and y:200.0
# width:2000.0 and height:23.0
# x:500.0 and y:200.0
# width:2000.0 and height:21.0
# x:500.0 and y:200.0
# width:2000.0 and height:21.0
# x:500.0 and y:200.0
# width:2000.0 and height:20.0
# x:500.0 and y:200.0
# width:2000.0 and height:20.0
# x:500.0 and y:200.0
# width:2000.0 and height:18.0
# x:500.0 and y:200.0
# width:2000.0 and height:18.0
# x:500.0 and y:200.0
# width:2000.0 and height:17.0
# x:500.0 and y:200.0
# width:2000.0 and height:17.0
# x:500.0 and y:200.0
# width:2000.0 and height:15.0
# x:500.0 and y:200.0
# width:2000.0 and height:15.0
# x:500.0 and y:200.0
# width:2000.0 and height:14.0
# x:500.0 and y:200.0
# width:2000.0 and height:14.0
# x:500.0 and y:200.0
# width:2000.0 and height:13.0
# x:500.0 and y:200.0
# width:2000.0 and height:13.0
# x:500.0 and y:200.0
# width:2000.0 and height:11.0
# x:500.0 and y:200.0
# width:2000.0 and height:11.0
# x:500.0 and y:200.0
# width:2000.0 and height:10.0
# x:500.0 and y:200.0
# width:2000.0 and height:10.0
# x:500.0 and y:200.0
# width:2000.0 and height:8.0
# x:500.0 and y:200.0
# width:2000.0 and height:8.0
# x:500.0 and y:200.0
# width:2000.0 and height:10.0
# x:500.0 and y:200.0
# width:2000.0 and height:10.0
# x:500.0 and y:200.0
# width:2000.0 and height:11.0
# x:500.0 and y:200.0
# width:2000.0 and height:11.0
# x:500.0 and y:200.0
# width:2000.0 and height:13.0
# x:500.0 and y:200.0
# width:2000.0 and height:13.0
# x:500.0 and y:200.0
# width:2000.0 and height:14.0
# x:500.0 and y:200.0
# width:2000.0 and height:14.0
# x:500.0 and y:200.0
# width:2000.0 and height:15.0
# x:500.0 and y:200.0
# width:2000.0 and height:15.0
# x:500.0 and y:200.0
# width:2000.0 and height:17.0
# x:500.0 and y:200.0
# width:2000.0 and height:17.0
# x:500.0 and y:200.0
# width:2000.0 and height:18.0
# x:500.0 and y:200.0
# width:2000.0 and height:18.0
# x:500.0 and y:200.0
# width:2000.0 and height:20.0
# x:500.0 and y:200.0
# width:2000.0 and height:20.0
# x:500.0 and y:200.0
# width:2000.0 and height:21.0
# x:500.0 and y:200.0
# width:2000.0 and height:21.0
# x:500.0 and y:200.0
# width:2000.0 and height:23.0
# x:500.0 and y:200.0
# width:2000.0 and height:23.0
# x:500.0 and y:200.0
# width:2000.0 and height:24.0
# x:500.0 and y:200.0
# width:2000.0 and height:24.0
# x:500.0 and y:200.0
# width:2000.0 and height:25.0
# x:500.0 and y:200.0
# width:2000.0 and height:25.0
# x:500.0 and y:200.0
# width:2000.0 and height:27.0
# x:500.0 and y:200.0
# width:2000.0 and height:27.0
# x:500.0 and y:200.0
# width:2000.0 and height:28.0
# x:500.0 and y:200.0
# width:2000.0 and height:28.0
# x:500.0 and y:200.0
# width:2000.0 and height:30.0
# x:500.0 and y:200.0
# width:2000.0 and height:30.0
# x:500.0 and y:200.0
# width:2000.0 and height:31.0
# x:500.0 and y:200.0
# width:2000.0 and height:31.0
# x:500.0 and y:200.0
# width:2000.0 and height:34.0
# x:500.0 and y:200.0
# width:2000.0 and height:34.0
# x:500.0 and y:200.0
# width:2000.0 and height:36.0
# x:500.0 and y:200.0
# width:2000.0 and height:36.0
# x:500.0 and y:200.0
# width:2000.0 and height:37.0
# x:500.0 and y:200.0
# width:2000.0 and height:37.0
# x:500.0 and y:200.0
# width:2000.0 and height:38.0
# x:500.0 and y:200.0
# width:2000.0 and height:38.0
# x:500.0 and y:200.0
# width:2000.0 and height:40.0
# x:500.0 and y:200.0
# width:2000.0 and height:40.0
# x:500.0 and y:200.0
# width:2000.0 and height:41.0
# x:500.0 and y:200.0
# width:2000.0 and height:41.0
# x:500.0 and y:200.0
# width:2000.0 and height:43.0
# x:500.0 and y:200.0
# width:2000.0 and height:43.0
# x:500.0 and y:200.0
# width:2000.0 and height:44.0
# x:500.0 and y:200.0
# width:2000.0 and height:44.0
# x:500.0 and y:200.0
# width:2000.0 and height:46.0
# x:500.0 and y:200.0
# width:2000.0 and height:46.0
# x:500.0 and y:200.0
# width:2000.0 and height:47.0
# x:500.0 and y:200.0
# width:2000.0 and height:47.0
# x:500.0 and y:200.0
# width:2000.0 and height:48.0
# x:500.0 and y:200.0
# width:2000.0 and height:48.0
# x:500.0 and y:200.0
# width:2000.0 and height:50.0
# x:500.0 and y:200.0
# width:2000.0 and height:50.0
# x:500.0 and y:200.0
# width:2000.0 and height:51.0
# x:500.0 and y:200.0
# width:2000.0 and height:51.0
# x:500.0 and y:200.0
# width:2000.0 and height:54.0
# x:500.0 and y:200.0
# width:2000.0 and height:54.0
# x:500.0 and y:200.0
# width:2000.0 and height:56.0
# x:500.0 and y:200.0
# width:2000.0 and height:56.0
# x:500.0 and y:200.0
# width:2000.0 and height:57.0
# x:500.0 and y:200.0
# width:2000.0 and height:57.0
# x:500.0 and y:200.0
# width:2000.0 and height:59.0
# x:500.0 and y:200.0
# width:2000.0 and height:59.0
# x:500.0 and y:200.0
# width:2000.0 and height:60.0
# x:500.0 and y:200.0
# width:2000.0 and height:60.0
# x:500.0 and y:200.0
# width:2000.0 and height:61.0
# x:500.0 and y:200.0
# width:2000.0 and height:61.0
# x:500.0 and y:200.0
# width:2000.0 and height:63.0
# x:500.0 and y:200.0
# width:2000.0 and height:63.0
# x:500.0 and y:200.0
# width:2000.0 and height:64.0
# x:500.0 and y:200.0
# width:2000.0 and height:64.0
# x:500.0 and y:200.0
# width:2000.0 and height:66.0
# x:500.0 and y:200.0
# width:2000.0 and height:66.0
# x:500.0 and y:200.0
# width:2000.0 and height:67.0
# x:500.0 and y:200.0
# width:2000.0 and height:67.0
# x:500.0 and y:200.0
# width:2000.0 and height:69.0
# x:500.0 and y:200.0
# width:2000.0 and height:69.0
# x:500.0 and y:200.0
# width:2000.0 and height:70.0
# x:500.0 and y:200.0
# width:2000.0 and height:70.0
# x:500.0 and y:200.0
# width:2000.0 and height:71.0
# x:500.0 and y:200.0
# width:2000.0 and height:71.0
# x:500.0 and y:200.0
# width:2000.0 and height:73.0
# x:500.0 and y:200.0
# width:2000.0 and height:73.0
# x:500.0 and y:200.0
# width:2000.0 and height:74.0
# x:500.0 and y:200.0
# width:2000.0 and height:74.0
# x:518.4458801269029 and y:200.0
# width:2000.0 and height:74.0
# x:518.4458801269029 and y:218.44588012690224
# width:2000.0 and height:74.0
# x:536.8917602538058 and y:236.89176025380448
# width:2000.0 and height:74.0
# x:536.891760253804 and y:236.89176025380436
# width:2000.0 and height:74.0
# x:536.8917602538058 and y:236.89176025380436
# width:2000.0 and height:74.0
# x:555.3376403807051 and y:255.3376403807065
# width:2000.0 and height:74.0
# x:555.337640380707 and y:255.3376403807066
# width:2000.0 and height:74.0
# x:555.337640380707 and y:273.78352050760884
# width:2000.0 and height:74.0
# x:573.7835205076099 and y:273.7835205076087
# width:2000.0 and height:74.0
# x:573.783520507608 and y:273.78352050760884
# width:2000.0 and height:74.0
# x:573.783520507608 and y:292.22940063451085
# width:2000.0 and height:74.0
# x:592.2294006345091 and y:292.22940063451097
# width:2000.0 and height:74.0
# x:592.229400634511 and y:310.6752807614132
# width:2000.0 and height:74.0
# x:610.6752807614139 and y:329.12116088831533
# width:2000.0 and height:74.0
# x:629.121160888315 and y:347.5670410152177
# width:2000.0 and height:74.0
# x:629.121160888315 and y:366.0129211421198
# width:2000.0 and height:74.0
# x:647.5670410152179 and y:384.4588012690218
# width:2000.0 and height:74.0
# x:647.5670410152179 and y:402.9046813959242
# width:2000.0 and height:74.0
# x:666.0129211421208 and y:402.9046813959242
# width:2000.0 and height:74.0
# x:666.012921142119 and y:402.9046813959242
# width:2000.0 and height:74.0
# x:666.012921142119 and y:421.3505615228263
# width:2000.0 and height:74.0
# x:684.4588012690201 and y:458.2423217766309
# width:2000.0 and height:74.0
# x:684.4588012690219 and y:476.688201903533
# width:2000.0 and height:74.0
# x:702.9046813959249 and y:495.134082030435
# width:2000.0 and height:74.0
# x:702.9046813959249 and y:513.5799621573373
# width:2000.0 and height:74.0
# x:702.9046813959249 and y:532.0258422842396
# width:2000.0 and height:74.0
# x:702.9046813959249 and y:550.4717224111417
# width:2000.0 and height:74.0
# x:702.9046813959249 and y:568.9176025380439
# width:2000.0 and height:74.0
# x:721.350561522826 and y:568.917602538044
# width:2000.0 and height:74.0
# x:721.350561522826 and y:587.3634826649459
# width:2000.0 and height:74.0
# x:721.350561522826 and y:605.8093627918482
# width:2000.0 and height:74.0
# x:721.350561522826 and y:624.2552429187504
# width:2000.0 and height:74.0
# x:721.350561522826 and y:642.7011230456527
# width:2000.0 and height:74.0
# x:702.9046813959249 and y:642.7011230456528
# width:2000.0 and height:74.0
# x:702.9046813959249 and y:661.147003172555
# width:2000.0 and height:74.0
# x:684.4588012690219 and y:679.5928832994568
# width:2000.0 and height:74.0
# x:684.4588012690219 and y:698.0387634263592
# width:2000.0 and height:74.0
# x:666.0129211421208 and y:698.0387634263593
# width:2000.0 and height:74.0
# x:666.012921142119 and y:698.0387634263592
# width:2000.0 and height:74.0
# x:647.5670410152161 and y:716.4846435532615
# width:2000.0 and height:74.0
# x:629.1211608883132 and y:716.4846435532614
# width:2000.0 and height:74.0
# x:629.121160888315 and y:716.4846435532615
# width:2000.0 and height:74.0
# x:629.121160888315 and y:734.9305236801637
# width:2000.0 and height:74.0
# x:610.6752807614139 and y:734.9305236801638
# width:2000.0 and height:74.0
# x:592.229400634511 and y:734.9305236801637
# width:2000.0 and height:74.0
# x:592.229400634511 and y:716.4846435532615
# width:2000.0 and height:74.0
# x:592.229400634511 and y:698.0387634263592
# width:2000.0 and height:74.0
# x:573.7835205076099 and y:698.0387634263593
# width:2000.0 and height:74.0
# x:555.3376403807051 and y:679.592883299457
# width:2000.0 and height:74.0
# x:555.337640380707 and y:679.5928832994571
# width:2000.0 and height:74.0
# x:536.8917602538058 and y:679.592883299457
# width:2000.0 and height:74.0
# x:518.4458801269011 and y:679.5928832994571
# width:2000.0 and height:74.0
# x:499.9999999999982 and y:679.592883299457
# width:2000.0 and height:74.0
# x:481.5541198730989 and y:661.1470031725551
# width:2000.0 and height:74.0
# x:463.10823974619416 and y:661.147003172555
# width:2000.0 and height:74.0
# x:463.108239746196 and y:661.1470031725548
# width:2000.0 and height:74.0
# x:444.6623596192949 and y:661.147003172555
# width:2000.0 and height:74.0
# x:444.66235961929306 and y:661.1470031725548
# width:2000.0 and height:74.0
# x:444.6623596192949 and y:661.147003172555
# width:2000.0 and height:74.0
# x:444.66235961929306 and y:661.1470031725548
# width:2000.0 and height:74.0
# x:426.21647949239195 and y:661.147003172555
# width:2000.0 and height:74.0
# x:407.77059936548903 and y:661.1470031725548
# width:2000.0 and height:74.0
# x:389.32471923858793 and y:661.147003172555
# width:2000.0 and height:74.0
# x:389.3247192385861 and y:661.1470031725548
# width:2000.0 and height:74.0
# x:370.8788391116832 and y:661.147003172555
# width:2000.0 and height:74.0
# x:370.878839111685 and y:661.1470031725548
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:661.147003172555
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:661.1470031725548
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:661.147003172555
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:661.1470031725548
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:661.147003172555
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:679.5928832994568
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:679.592883299457
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:698.0387634263593
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:698.0387634263592
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:698.0387634263593
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:716.4846435532614
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:716.4846435532615
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:716.4846435532614
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:734.9305236801638
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:734.9305236801637
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:734.9305236801638
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:734.9305236801637
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:753.376403807066
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:753.3764038070657
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:753.3764038070658
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:753.3764038070659
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:753.3764038070658
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:753.3764038070659
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:753.3764038070658
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:753.3764038070659
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:753.3764038070658
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:771.8222839339679
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:771.822283933968
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:771.8222839339682
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:771.822283933968
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:771.8222839339682
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:771.822283933968
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:771.8222839339682
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:771.822283933968
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:790.2681640608704
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:790.26816406087
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:790.2681640608702
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:790.2681640608703
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:790.2681640608702
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:790.2681640608703
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:790.2681640608702
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:790.2681640608703
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:790.2681640608702
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:790.2681640608703
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:790.2681640608702
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:790.2681640608703
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:808.7140441877724
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:808.7140441877725
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:808.7140441877724
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:808.7140441877725
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:808.7140441877724
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:808.7140441877725
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:808.7140441877724
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:808.7140441877725
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:808.7140441877724
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:808.7140441877725
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:827.1599243146746
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:827.1599243146748
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:827.1599243146746
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:827.1599243146748
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:827.1599243146746
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:827.1599243146748
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:827.1599243146746
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:827.1599243146748
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:827.1599243146746
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:827.1599243146748
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:827.1599243146746
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:845.605804441577
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:845.6058044415767
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:845.6058044415768
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:845.6058044415769
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:845.6058044415768
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:845.6058044415769
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:845.6058044415768
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:845.6058044415769
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:845.6058044415768
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:845.6058044415769
# width:2000.0 and height:74.0
# x:370.8788391116832 and y:845.6058044415768
# width:2000.0 and height:74.0
# x:370.878839111685 and y:845.6058044415769
# width:2000.0 and height:74.0
# x:352.4329589847839 and y:845.6058044415768
# width:2000.0 and height:74.0
# x:352.4329589847821 and y:845.6058044415769
# width:2000.0 and height:74.0
# x:333.987078857881 and y:845.6058044415768
# width:2000.0 and height:74.0
# x:315.54119873097807 and y:845.6058044415769
# width:2000.0 and height:74.0
# x:315.54119873097807 and y:864.0516845684788
# width:2000.0 and height:74.0
# x:297.09531860407697 and y:864.0516845684789
# width:2000.0 and height:74.0
# x:297.09531860407515 and y:864.051684568479
# width:2000.0 and height:74.0
