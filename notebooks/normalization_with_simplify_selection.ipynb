# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.pages.ornl.gov/tutorial/notebooks/normalization_with_simplify_selection)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code.normalization_with_simplify_selection import NormalizationWithSimplifySelection
from __code import system
system.System.select_working_dir()
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ** Using Debugging Mode! **
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %% [markdown]
# # Select List of Images to Normalize

# %% [markdown]
# Program will create a full table of the normalization workflow according to the **acquisition time** and **instrument configurations**.
#
# Change the time range if needed!

# %%
print(o_which.final_full_master_dict[30.0]['config0']['list_ob'])
# Out:
# [{'filename': '/Users/j35/IPTS/IPTS-20267-Jonathan/raw/ob/Jan09_2020_sam3_Cineole_LightOn/20200109_sam3_Cineole_LightOn_0030_2074.tiff', 'time_stamp': 1578609083.3096735, 'time_stamp_user_format': '2020-01-09 17:31:23', 65027: {'value': 30.0, 'name': 'EXPOSURE_TIME'}, 65026: {'value': 'Andor', 'name': 'DETECTOR_MANUFACTURER'}, 65068: {'value': 40.0, 'name': 'APERTURE_HR'}, 65070: {'value': 40.0, 'name': 'APERTURE_HL'}, 65066: {'value': 40.0, 'name': 'APERTURE_VT'}, 65064: {'value': 40.0, 'name': 'APERTURE_VB'}}, {'filename': '/Users/j35/IPTS/IPTS-20267-Jonathan/raw/ob/Jan09_2020_sam3_Cineole_LightOn/20200109_sam3_Cineole_LightOn_0030_2097.tiff', 'time_stamp': 1578610673.9556408, 'time_stamp_user_format': '2020-01-09 17:57:53', 65027: {'value': 30.0, 'name': 'EXPOSURE_TIME'}, 65026: {'value': 'Andor', 'name': 'DETECTOR_MANUFACTURER'}, 65068: {'value': 40.0, 'name': 'APERTURE_HR'}, 65070: {'value': 40.0, 'name': 'APERTURE_HL'}, 65066: {'value': 40.0, 'name': 'APERTURE_VT'}, 65064: {'value': 40.0, 'name': 'APERTURE_VB'}}, {'filename': '/Users/j35/IPTS/IPTS-20267-Jonathan/raw/ob/Jan09_2020_sam3_Cineole_LightOn/20200109_sam3_Cineole_LightOn_0030_2078.tiff', 'time_stamp': 1578609369.2771454, 'time_stamp_user_format': '2020-01-09 17:36:09', 65027: {'value': 30.0, 'name': 'EXPOSURE_TIME'}, 65026: {'value': 'Andor', 'name': 'DETECTOR_MANUFACTURER'}, 65068: {'value': 40.0, 'name': 'APERTURE_HR'}, 65070: {'value': 40.0, 'name': 'APERTURE_HL'}, 65066: {'value': 40.0, 'name': 'APERTURE_VT'}, 65064: {'value': 40.0, 'name': 'APERTURE_VB'}}, {'filename': '/Users/j35/IPTS/IPTS-20267-Jonathan/raw/ob/Jan09_2020_sam3_Cineole_LightOn/20200109_sam3_Cineole_LightOn_0030_2081.tiff', 'time_stamp': 1578609557.1574163, 'time_stamp_user_format': '2020-01-09 17:39:17', 65027: {'value': 30.0, 'name': 'EXPOSURE_TIME'}, 65026: {'value': 'Andor', 'name': 'DETECTOR_MANUFACTURER'}, 65068: {'value': 40.0, 'name': 'APERTURE_HR'}, 65070: {'value': 40.0, 'name': 'APERTURE_HL'}, 65066: {'value': 40.0, 'name': 'APERTURE_VT'}, 65064: {'value': 40.0, 'name': 'APERTURE_VB'}}, {'filename': '/Users/j35/IPTS/IPTS-20267-Jonathan/raw/ob/Jan09_2020_sam3_Cineole_LightOn/20200109_sam3_Cineole_LightOn_0030_2080.tiff', 'time_stamp': 1578609465.128033, 'time_stamp_user_format': '2020-01-09 17:37:45', 65027: {'value': 30.0, 'name': 'EXPOSURE_TIME'}, 65026: {'value': 'Andor', 'name': 'DETECTOR_MANUFACTURER'}, 65068: {'value': 40.0, 'name': 'APERTURE_HR'}, 65070: {'value': 40.0, 'name': 'APERTURE_HL'}, 65066: {'value': 40.0, 'name': 'APERTURE_VT'}, 65064: {'value': 40.0, 'name': 'APERTURE_VB'}}, {'filename': '/Users/j35/IPTS/IPTS-20267-Jonathan/raw/ob/Jan09_2020_sam3_Cineole_LightOn/20200109_sam3_Cineole_LightOn_0030_2096.tiff', 'time_stamp': 1578610625.833556, 'time_stamp_user_format': '2020-01-09 17:57:05', 65027: {'value': 30.0, 'name': 'EXPOSURE_TIME'}, 65026: {'value': 'Andor', 'name': 'DETECTOR_MANUFACTURER'}, 65068: {'value': 40.0, 'name': 'APERTURE_HR'}, 65070: {'value': 40.0, 'name': 'APERTURE_HL'}, 65066: {'value': 40.0, 'name': 'APERTURE_VT'}, 65064: {'value': 40.0, 'name': 'APERTURE_VB'}}, {'filename': '/Users/j35/IPTS/IPTS-20267-Jonathan/raw/ob/Jan09_2020_sam3_Cineole_LightOn/20200109_sam3_Cineole_LightOn_0030_2079.tiff', 'time_stamp': 1578609417.3993547, 'time_stamp_user_format': '2020-01-09 17:36:57', 65027: {'value': 30.0, 'name': 'EXPOSURE_TIME'}, 65026: {'value': 'Andor', 'name': 'DETECTOR_MANUFACTURER'}, 65068: {'value': 40.0, 'name': 'APERTURE_HR'}, 65070: {'value': 40.0, 'name': 'APERTURE_HL'}, 65066: {'value': 40.0, 'name': 'APERTURE_VT'}, 65064: {'value': 40.0, 'name': 'APERTURE_VB'}}, {'filename': '/Users/j35/IPTS/IPTS-20267-Jonathan/raw/ob/Jan09_2020_sam3_Cineole_LightOn/20200109_sam3_Cineole_LightOn_0030_2075.tiff', 'time_stamp': 1578609131.37566, 'time_stamp_user_format': '2020-01-09 17:32:11', 65027: {'value': 30.0, 'name': 'EXPOSURE_TIME'}, 65026: {'value': 'Andor', 'name': 'DETECTOR_MANUFACTURER'}, 65068: {'value': 40.0, 'name': 'APERTURE_HR'}, 65070: {' ...

# %%
o_which = NormalizationWithSimplifySelection(working_dir=system.System.get_working_dir())
o_which.select_sample_images_and_create_configuration()
# Out:
# VBox(children=(Label(value='select folder of images to normalize', layout=Layout(width='250px')), VBox(childre…
# HBox(children=(Label(value='Retrieving time stamp of sample', layout=Layout(width='20%')), IntProgress(value=0…
# HBox(children=(Label(value='Retrieving time stamp of ob', layout=Layout(width='20%')), IntProgress(value=0, la…
# HBox(children=(Label(value='Retrieving time stamp of df', layout=Layout(width='20%')), IntProgress(value=0, la…
# Tab(children=(Tab(children=(VBox(children=(HBox(children=(Checkbox(value=False, description='Use custom time r…

# %% [markdown]
# # Normalization workflow

# %%
o_which.checking_normalization_workflow()
# Out:
# HTML(value="<table style='width:50%;border:1px solid black'><tr style='background-color:#eee'><th>Acquisition …

# %% [markdown]
# # Select Output Folder

# %%
o_which.select_output_folder()
# Out:
# HBox(children=(Button(button_style='success', description='Jump to  Shared Folder', layout=Layout(border='1px …
# VBox(children=(Label(value='select where to create the normalized folders', layout=Layout(width='250px')), VBo…
# VBox(children=(Label(value='select where to create the normalized folders', layout=Layout(width='250px')), VBo…
# HBox(children=(Label(value='Normalization progress', layout=Layout(width='20%')), IntProgress(value=0, layout=…
# HBox(children=(Label(value='Loading sample', layout=Layout(width='20%')), IntProgress(value=0, max=291), Label…
# <span style="font-size: 20px; color:blue">Following folders have been created:</span>
# <span style="font-size: 15px; color:blue"> -> /SNS/users/j35/Desktop/Jan07_2020_30.0_config0</span>
