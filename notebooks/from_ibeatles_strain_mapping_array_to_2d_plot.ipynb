# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/from-ibeatles-strain-mapping-array-to-2d-plot/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
import warnings
warnings.filterwarnings('ignore')

from __code.from_ibeatles_strain_mapping_array_to_2d_plot.main import Main
from __code import system
system.System.select_working_dir()
from __code.__all import custom_style
custom_style.style()

# %matplotlib notebook
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ** Using Debugging Mode! **
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…

# %% [markdown]
# # Select ASCII file created in iBeatles (strain step)

# %%
#o_strain_display = Main(working_dir = system.System.get_working_dir())
o_strain_display = Main(working_dir = '/Users/j35/SNS/SNAP/IPTS-27829-Adrian/')
o_strain_display = Main(working_dir = '/Users/j35/SNS/SNAP/IPTS-27829/')

o_strain_display.select_ascii_file()
# Out:
# VBox(children=(Label(value='Select Ascii file', layout=Layout(width='250px')), VBox(children=(HBox(children=(H…
# <span style="font-size: 20px; color:blue">rewgon_1b_strain_mapping_table.txt has been loaded !</span>

# %% [markdown]
# # Display data

# %%
o_strain_display.process_data()
o_strain_display.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# step = 0.06867684582038198
# interactive(children=(FloatSlider(value=4.029369339559694, description='min_value', max=10.897053921597893, mi…
