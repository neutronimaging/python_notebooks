# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/venus_display_nexus_tpx3/)
#
# <img src='__docs/__all/notebook_rules.png'/>

# %% [markdown]
# # Select Your IPTS

# %%
from __code import system
from __code.venus_display_nexus_tpx3.main import VenusDisplayNexusTpx3

system.System.select_working_dir(facility='SNS', instrument='VENUS', ipts="IPTS-35817", instrument_to_exclude=["CG1D", "SNAP"])
from __code.__all import custom_style
custom_style.style()

# %matplotlib inline

# %% [markdown]
# # Define settings

# %%
o_nexus = VenusDisplayNexusTpx3(working_dir=system.System.get_working_dir())
o_nexus.define_settings()

# %% [markdown]
# # Select NeXus

# %%
o_nexus.select_event_nexus()
