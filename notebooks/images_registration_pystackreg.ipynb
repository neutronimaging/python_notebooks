# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/images_registration_using_pystackreg/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code.images_registration_pystackreg.main import ImagesRegistrationPystackreg

from __code import system
system.System.select_working_dir(notebook='images_registration_pystackreg')
from __code.__all import custom_style
custom_style.style()

# %matplotlib widget
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# Warning: netCDF4 module not found
# netCDF4 module not found
# ** Using Debugging Mode! **
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…

# %% [markdown]
# # Select images to register

# %%
o_register = ImagesRegistrationPystackreg(working_dir = system.System.get_working_dir())
o_register.select_folder()
# Out:
# VBox(children=(HTML(value="<b><font color='green'>select folder of images to register</b>"), VBox(children=(HB…

# %% [markdown]
# # Display unregistered images

# %%
o_register.display_unregistered()
# Out:
# interactive(children=(IntSlider(value=1, description='image_index', max=196), FloatSlider(value=0.8, descripti…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Crop images

# %%
o_register.crop_unregistered_images()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
