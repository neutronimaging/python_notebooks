# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/venus_monitor_hdf5/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code import system
from __code.venus_chop_tcero_monitor_counts.main import VenusChopTCeroMonitorCounts

import h5py
import numpy as np

system.System.select_working_dir(facility='SNS', instrument='VENUS')
from __code.__all import custom_style
custom_style.style()

import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(index=2, la…

# %%
# %matplotlib notebook

# %% [markdown]
# # Define settings

# %%
#o_event = VenusChopTCeroMonitorCounts(working_dir=system.System.get_working_dir())
o_event = VenusChopTCeroMonitorCounts(working_dir="/SNS/VENUS/IPTS-33699")
#o_event.select_list_nexus()

# debugging (loading all runs from 520 to 599)
import glob
#list_nexus = glob.glob("/SNS/VENUS/IPTS-33699/nexus/VENUS_5[23456789]*.nxs.h5")
list_nexus = glob.glob("/SNS/VENUS/IPTS-33699/nexus/VENUS_4[6789]*.nxs.h5")
o_event.load_data(list_nexus)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <b>Report:</b>
# Phase delay at minimum: 720.0
# Index of NeXus at minimum: 29
# NeXus at minimum: /SNS/VENUS/IPTS-33699/nexus/VENUS_470.nxs.h5
# Start acquisition time: 2024-07-25T12:45:42.405019667-04:00
#
# List of nexus that had missing key: ['VENUS_490.nxs.h5', 'VENUS_489.nxs.h5']
