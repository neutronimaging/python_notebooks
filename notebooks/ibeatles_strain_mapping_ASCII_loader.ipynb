# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/from-ibeatles-strain-mapping-array-to-2d-plot/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
import warnings
warnings.filterwarnings('ignore')

from __code.from_ibeatles_strain_mapping_array_to_2d_plot.main import Main
from __code import system
system.System.select_working_dir()
from __code.__all import custom_style
custom_style.style()

# %matplotlib notebook
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# <span style="font-size: 15px; color:blue">working dir set to -> /Users/j35</span>

# %% [markdown]
# # Select ASCII file created in iBeatles (strain step)

# %%
o_strain_display = Main(working_dir = system.System.get_working_dir())
#select_ascii_file = "/Users/j35/Desktop/strain_mapping_table_y2023_m10_d19_h09_mn38.txt"
select_ascii_file = "/Users/j35/Desktop/strain_mapping_table_y2023_m10_d20_h07_mn42.txt"
o_strain_display.load(select_ascii_file)
# o_strain_display.select_ascii_file()
# Out:
# <span style="font-size: 20px; color:blue">strain_mapping_table_y2023_m10_d20_h07_mn42.txt has been loaded !</span>

# %% [markdown]
# # Display data

# %%
o_strain_display.process_data()
o_strain_display.display()
# Out:
# <img src="data:image/png;base64,..." width="400">
# interactive(children=(FloatSlider(value=2.6060129175602396, description='min_value', max=2.6590903866703424, m…
# <img src="data:image/png;base64,..." width="400">
# interactive(children=(FloatSlider(value=1.3030064587801198, description='min_value', max=1.3295451933351712, m…
# <img src="data:image/png;base64,..." width="500">
# interactive(children=(FloatSlider(value=33312.021237208406, description='min_value', max=54357.8059755521, min…
