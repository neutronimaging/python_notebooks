# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.pages.ornl.gov/tutorial/notebooks/extract_evenly_spaced_files)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code.extract_evenly_spaced_files.main import ExtractEvenlySpacedFiles as EESF
from __code.extract_evenly_spaced_files.interface_handler import Interface
from __code import system
system.System.select_working_dir()
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ** Using Debugging Mode! **
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %%
# %gui qt

# %% [markdown]
# # Select Folder with Images to Extract

# %% [markdown]
# # DEBUGGING

# %%
o_extract = EESF("/Volumes/G-DRIVE/IPTS/IPTS_extract_files_from_folder/")
o_extract.retrieve_list_of_files("/Volumes/G-DRIVE/IPTS/IPTS_extract_files_from_folder/")
# Out:
# <span style="font-size: 15px; color:blue">51 files will be used in the extraction.</span>

# %%
o_extract.how_to_extract()
# Out:
# VBox(children=(HBox(children=(Label(value='Extract 1 over ', layout=Layout(width='10%')), Dropdown(index=1, la…

# %%
o_inteface = Interface(o_extract=o_extract)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/HistogramLUTItem.py in imageChanged(self, autoLevel, autoRange)
#     222             if h[0] is None:
#     223                 return
# --> 224             self.plot.setData(*h)
#     225             profiler('set plot')
#     226             if autoLevel:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/PlotCurveItem.py in setData(self, *args, **kargs)
#     333
#     334         """
# --> 335         self.updateData(*args, **kargs)
#     336
#     337     def updateData(self, *args, **kargs):
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/PlotCurveItem.py in updateData(self, *args, **kargs)
#     371         self.invalidateBounds()
#     372         self.prepareGeometryChange()
# --> 373         self.informViewBoundsChanged()
#     374
#     375         profiler('copy')
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/GraphicsItem.py in informViewBoundsChanged(self)
#     562         view = self.getViewBox()
#     563         if view is not None and hasattr(view, 'implements') and view.implements('ViewBox'):
# --> 564             view.itemBoundsChanged(self)  ## inform view so it can update its range if it wants
#     565
#     566     def childrenShape(self):
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/ViewBox/ViewBox.py in itemBoundsChanged(self, item)
#    1085         if (self.state['autoRange'][0] is not False) or (self.state['autoRange'][1] is not False):
#    1086             self._autoRangeNeedsUpdate = True
# -> 1087             self.update()
#    1088         #self.updateAutoRange()
#    1089
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/ViewBox/ViewBox.py in update(self, *args, **kwargs)
#     296
#     297     def update(self, *args, **kwargs):
# --> 298         self.prepareForPaint()
#     299         GraphicsWidget.update(self, *args, **kwargs)
#     300
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/ViewBox/ViewBox.py in prepareForPaint(self)
#     303         # don't check whether auto range is enabled here--only check when setting dirty flag.
#     304         if self._autoRangeNeedsUpdate: # and autoRangeEnabled:
# --> 305             self.updateAutoRange()
#     306         self.updateMatrix()
#     307
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/ViewBox/ViewBox.py in updateAutoRange(self)
#     907                 else:
#     908                     if childRange is None:
# --> 909                         childRange = self.childrenBounds(frac=fractionVisible)
#     910
#     911                 ## Make corrections to range
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/ViewBox/ViewBox.py in childrenBounds(self, frac, orthoRange, items)
#    1374
#    1375         ## measure pixel dimensions in view box
# -> 1376         px, py = [v.length() if v is not None else 0 for v in self.childGroup.pixelVectors()]
#    1377
#    1378         ## First collect all boundary information
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/graphicsItems/GraphicsItem.py in pixelVectors(self, direction)
#     199         ## check local cache
#     200         if key == self._pixelVectorCache[0]:
# --> 201             return tuple(map(Point, self._pixelVectorCache[1]))  ## return a *copy*
#     202
#     203         ## check global cache
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pyqtgraph/Point.py in __init__(self, *args)
#      21     def __init__(self, *args):
#      22         if len(args) == 1:
# ---> 23             if isinstance(args[0], QtCore.QSizeF):
#      24                 QtCore.QPointF.__init__(self, float(args[0].width()), float(args[0].height()))
#      25                 return
#
# RecursionError: maximum recursion depth exceeded in __instancecheck__
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/interface_handler.py in replace_by_list_changed(self, new_index)
#     102     def replace_by_list_changed(self, new_index):
#     103         o_event = EventHandler(parent=self)
# --> 104         o_event.replace_by_list_changed(new_index)
#     105
#     106     def remove_this_file_clicked(self):
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in replace_by_list_changed(self, new_index)
#     131         new_file = self.parent.ui.replace_by_comboBox.currentText()
#     132
# --> 133         new_data = self.load_file(file=new_file)
#     134
#     135         o_list = ListWidget(ui=self.parent.ui.list_of_files_listWidget)
#
# ~/git/python_notebooks/notebooks/__code/extract_evenly_spaced_files/event_handler.py in load_file(self, file)
#      18         o_norm = Normalization()
#      19         o_norm.load(file=file, notebook=False)
# ---> 20         _data = o_norm.data['sample']['data'][0]
#      21         return _data
#      22
#
# TypeError: 'NoneType' object is not subscriptable

# %%
o_extract = EESF(working_dir=system.System.get_working_dir())
o_extract.select_folder()
# Out:
# VBox(children=(Label(value='select folder with images to combine', layout=Layout(width='250px')), VBox(childre…

# %% [markdown]
# # Extraction Method to Use

# %%
o_extract.how_to_extract()

# %% [markdown]
# # Renamed files ?

# %% [markdown]
# This will replace the last part of the name (file counter digit)
#
# for example:
#
#     original first file:  20191030_object1_0070_004_594_0003.tiff
#     new first file name:  20191030_object1_0070_004_594_0000.tiff

# %%
o_extract.renamed_files()

# %% [markdown]
# # Select Output Folder

# %%
o_extract.select_output_folder()
