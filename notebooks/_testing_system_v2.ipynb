# %%
from __code.system_v2 import System

# %%
System.select_working_dir(verbose=True, instruments=["VENUS"])
# Out:
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ...

# %%
System.get_working_dir()
