# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorial/notebooks/timepix3_from_event_to_hito_hdf5)
#
# <img src='__docs/__all/notebook_rules.png' />

# %%
from __code import system
from __code.venus_monitor_hdf5.main import VenusMonitorHdf5

import h5py
import numpy as np

system.System.select_working_dir(facility='SNS', instrument='SNAP')
from __code.__all import custom_style
custom_style.style()

import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# ** Using Debugging Mode! **
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…

# %% [markdown]
# # Select Your IPTS

# %% [markdown]
# # Select Event NeXus

# %%
o_event = VenusMonitorHdf5(working_dir=system.System.get_working_dir())
o_event.select_event_nexus()
# Out:
# VBox(children=(HTML(value="<b><font color='green'>Select NeXus file ...</b>"), VBox(children=(HBox(children=(H…

# %% [markdown]
# # Display profile

# %%
nbr_bins = 100

distance_source_detector_m = 23.726   # m
distance_source_detector_cm = 2372.6   # cm

detector_offset_micros = 0  # micros

# %%
# %matplotlib inline

# %%
o_event.display_data_tof(nbr_bins=100)

# plt.figure(num='index')
# plt.plot(o_event.index)

# %%
o_event.display_data_lambda(distance_source_detector_m=distance_source_detector_m,
                            detector_offset_micros=detector_offset_micros)
