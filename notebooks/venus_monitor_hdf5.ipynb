# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/venus_monitor_hdf5/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code import system
from __code.venus_monitor_hdf5.main import VenusMonitorHdf5

import h5py
import numpy as np

system.System.select_working_dir(facility='SNS', instrument='VENUS')
from __code.__all import custom_style
custom_style.style()

import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(index=2, la…

# %%
# %matplotlib inline

# %% [markdown]
# # Define settings

# %%
o_event = VenusMonitorHdf5(working_dir=system.System.get_working_dir())
o_event.define_settings()
# Out:
# VBox(children=(HBox(children=(Label(value='Bins size (µs)'), IntSlider(value=100, max=10000, min=1))), HBox(ch…

# %% [markdown]
# # Select Event NeXus

# %%
# %matplotlib notebook

# %%
o_event.select_event_nexus()
# Out:
# entries_files =['VENUS_999.nxs.h5', 'VENUS_998.nxs.h5', 'VENUS_997.nxs.h5', 'VENUS_996.nxs.h5', 'VENUS_995.nxs.h5', 'VENUS_994.nxs.h5', 'VENUS_993.nxs.h5', 'VENUS_992.nxs.h5', 'VENUS_991.nxs.h5', 'VENUS_990.nxs.h5', 'VENUS_989.nxs.h5', 'VENUS_988.nxs.h5', 'VENUS_987.nxs.h5', 'VENUS_986.nxs.h5', 'VENUS_985.nxs.h5', 'VENUS_984.nxs.h5', 'VENUS_983.nxs.h5', 'VENUS_982.nxs.h5', 'VENUS_981.nxs.h5', 'VENUS_980.nxs.h5', 'VENUS_979.nxs.h5', 'VENUS_978.nxs.h5', 'VENUS_977.nxs.h5', 'VENUS_976.nxs.h5', 'VENUS_975.nxs.h5', 'VENUS_974.nxs.h5', 'VENUS_973.nxs.h5', 'VENUS_972.nxs.h5', 'VENUS_971.nxs.h5', 'VENUS_970.nxs.h5', 'VENUS_969.nxs.h5', 'VENUS_968.nxs.h5', 'VENUS_967.nxs.h5', 'VENUS_966.nxs.h5', 'VENUS_965.nxs.h5', 'VENUS_964.nxs.h5', 'VENUS_963.nxs.h5', 'VENUS_962.nxs.h5', 'VENUS_961.nxs.h5', 'VENUS_960.nxs.h5', 'VENUS_959.nxs.h5', 'VENUS_958.nxs.h5', 'VENUS_957.nxs.h5', 'VENUS_956.nxs.h5', 'VENUS_955.nxs.h5', 'VENUS_954.nxs.h5', 'VENUS_953.nxs.h5', 'VENUS_952.nxs.h5', 'VENUS_951.nxs.h5', 'VENUS_950.nxs.h5', 'VENUS_949.nxs.h5', 'VENUS_948.nxs.h5', 'VENUS_947.nxs.h5', 'VENUS_946.nxs.h5', 'VENUS_945.nxs.h5', 'VENUS_944.nxs.h5', 'VENUS_943.nxs.h5', 'VENUS_942.nxs.h5', 'VENUS_941.nxs.h5', 'VENUS_940.nxs.h5', 'VENUS_939.nxs.h5', 'VENUS_938.nxs.h5', 'VENUS_937.nxs.h5', 'VENUS_936.nxs.h5', 'VENUS_935.nxs.h5', 'VENUS_934.nxs.h5', 'VENUS_933.nxs.h5', 'VENUS_932.nxs.h5', 'VENUS_931.nxs.h5', 'VENUS_930.nxs.h5', 'VENUS_929.nxs.h5', 'VENUS_928.nxs.h5', 'VENUS_927.nxs.h5', 'VENUS_926.nxs.h5', 'VENUS_925.nxs.h5', 'VENUS_924.nxs.h5', 'VENUS_923.nxs.h5', 'VENUS_922.nxs.h5', 'VENUS_921.nxs.h5', 'VENUS_920.nxs.h5', 'VENUS_919.nxs.h5', 'VENUS_918.nxs.h5', 'VENUS_917.nxs.h5', 'VENUS_916.nxs.h5', 'VENUS_915.nxs.h5', 'VENUS_914.nxs.h5', 'VENUS_913.nxs.h5', 'VENUS_912.nxs.h5', 'VENUS_911.nxs.h5', 'VENUS_910.nxs.h5', 'VENUS_909.nxs.h5', 'VENUS_908.nxs.h5', 'VENUS_907.nxs.h5', 'VENUS_906.nxs.h5', 'VENUS_905.nxs.h5', 'VENUS_904.nxs.h5', 'VENUS_903.nxs.h5', 'VENUS_902.nxs.h5', 'VENUS_901.nxs.h5', 'VENUS_900.nxs.h5', 'VENUS_899.nxs.h5', 'VENUS_898.nxs.h5', 'VENUS_897.nxs.h5', 'VENUS_896.nxs.h5', 'VENUS_895.nxs.h5', 'VENUS_894.nxs.h5', 'VENUS_893.nxs.h5', 'VENUS_892.nxs.h5', 'VENUS_891.nxs.h5', 'VENUS_890.nxs.h5', 'VENUS_889.nxs.h5', 'VENUS_888.nxs.h5', 'VENUS_887.nxs.h5', 'VENUS_886.nxs.h5', 'VENUS_885.nxs.h5', 'VENUS_884.nxs.h5', 'VENUS_883.nxs.h5', 'VENUS_882.nxs.h5', 'VENUS_881.nxs.h5', 'VENUS_880.nxs.h5', 'VENUS_879.nxs.h5', 'VENUS_878.nxs.h5', 'VENUS_877.nxs.h5', 'VENUS_876.nxs.h5', 'VENUS_875.nxs.h5', 'VENUS_874.nxs.h5', 'VENUS_873.nxs.h5', 'VENUS_872.nxs.h5', 'VENUS_871.nxs.h5', 'VENUS_870.nxs.h5', 'VENUS_869.nxs.h5', 'VENUS_868.nxs.h5', 'VENUS_867.nxs.h5', 'VENUS_866.nxs.h5', 'VENUS_865.nxs.h5', 'VENUS_864.nxs.h5', 'VENUS_863.nxs.h5', 'VENUS_862.nxs.h5', 'VENUS_861.nxs.h5', 'VENUS_860.nxs.h5', 'VENUS_859.nxs.h5', 'VENUS_858.nxs.h5', 'VENUS_857.nxs.h5', 'VENUS_856.nxs.h5', 'VENUS_855.nxs.h5', 'VENUS_854.nxs.h5', 'VENUS_853.nxs.h5', 'VENUS_852.nxs.h5', 'VENUS_851.nxs.h5', 'VENUS_850.nxs.h5', 'VENUS_849.nxs.h5', 'VENUS_848.nxs.h5', 'VENUS_847.nxs.h5', 'VENUS_846.nxs.h5', 'VENUS_845.nxs.h5', 'VENUS_844.nxs.h5', 'VENUS_843.nxs.h5', 'VENUS_842.nxs.h5', 'VENUS_841.nxs.h5', 'VENUS_840.nxs.h5', 'VENUS_839.nxs.h5', 'VENUS_838.nxs.h5', 'VENUS_837.nxs.h5', 'VENUS_836.nxs.h5', 'VENUS_835.nxs.h5', 'VENUS_834.nxs.h5', 'VENUS_833.nxs.h5', 'VENUS_832.nxs.h5', 'VENUS_831.nxs.h5', 'VENUS_830.nxs.h5', 'VENUS_829.nxs.h5', 'VENUS_828.nxs.h5', 'VENUS_827.nxs.h5', 'VENUS_826.nxs.h5', 'VENUS_825.nxs.h5', 'VENUS_824.nxs.h5', 'VENUS_823.nxs.h5', 'VENUS_822.nxs.h5', 'VENUS_821.nxs.h5', 'VENUS_820.nxs.h5', 'VENUS_819.nxs.h5', 'VENUS_818.nxs.h5', 'VENUS_817.nxs.h5', 'VENUS_816.nxs.h5', 'VENUS_815.nxs.h5', 'VENUS_814.nxs.h5', 'VENUS_813.nxs.h5', 'VENUS_812.nxs.h5', 'VENUS_811.nxs.h5', 'VENUS_810.nxs.h5', 'VENUS_809.nxs.h5', 'VENUS_808.nxs.h5', 'VENUS_807.nxs.h5', 'VENUS_806.nxs.h5', 'VENUS_805.nxs.h5', 'VENUS_804.nxs.h5', 'VENUS_803.nxs.h5', 'VENUS_802.nxs.h5', 'VENUS_801.nxs.h5', 'VEN ...
# VBox(children=(HTML(value="<b><font color='green'>Select NeXus file ...</b>"), VBox(children=(HBox(children=(H…

# %% [markdown]
# # Export

# %%
o_event.export_data()
