# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/timepix_chips_alignment_correction/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
import warnings
warnings.filterwarnings('ignore')

from __code import system
from __code.timepix_chips_alignment_correction.main import TimepixChipsAlignmentCorrection
system.System.select_working_dir(notebook='mcp_chips_corrector', instrument="VENUS", ipts="IPTS-35945")
from __code.__all import custom_style
custom_style.style()

# %% [markdown]
# # Select timepix data you want to correct

# %%
o_corrector = TimepixChipsAlignmentCorrection(working_dir = system.System.get_working_dir())
# o_corrector.select_folder()

# for debugging
folder = "/SNS/VENUS/IPTS-35945/shared/autoreduce/mcp/images/Run_8997"
o_corrector.load_data(folder_selected=folder)

# %% [markdown]
# # Select detector type

# %%
o_corrector.select_detector()

# %% [markdown]
# # Correction configuration

# %%
o_corrector.correction_settings()

# %% [markdown]
# # Select output folder

# %%
o_corrector.select_output_folder()
