# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/normalization/normalization_tof/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code.normalization_tof.normalization_tof import NormalizationTof

from __code import system
system.System.select_working_dir(notebook='normalization', instrument="VENUS", ipts="IPTS-36063")
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(index=2, la…
# <span style="font-size: 15px; color:blue">working dir set to -> /SNS/users/j35</span>
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %% [markdown]
# # Initialize notebook

# %%
o_norm = NormalizationTof(working_dir=system.System.get_working_dir(), debug=True)

# %% [markdown]
# <hr style="height: 2px" /><hr style="border-bottom: dotted 1px" />
# <font color='purple' size='5'>Manually set the runs and output folder</font><font color='purple' size='5'> - OPTIONAL</font>

# %%
o_norm.manually_set_runs()
# Out:
# VBox(children=(Label(value='List of sample run numbers (ex: 8702, 8704)'), Textarea(value='8702', layout=Layou…

# %% [markdown]
# <hr style="border-bottom: dotted 1px;" />
# <hr style="height: 2px" />

# %% [markdown]
# # Select list of runs to normalize

# %%
o_norm.select_sample_run_numbers()
# Out:
# Sample run numbers selected: <span style='color:blue'>/SNS/VENUS/IPTS-36063/shared/autoreduce/mcp/images/Run_8702, /SNS/VENUS/IPTS-36063/shared/autoreduce/mcp/images/Run_8704</span>

# %% [markdown]
# # Select list of open beam runs
#
# The OB runs will be combined and used on each of the sample runs

# %%
o_norm.select_ob_run_numbers()
# Out:
# OB run numbers selected: <span style='color:blue'>/SNS/VENUS/IPTS-36063/shared/autoreduce/mcp/images/Run_8703</span>

# %% [markdown]
# # Select Output Folder

# %%
o_norm.select_output_folder()
# Out:
# Output folder selected: <span style='color:blue'>/SNS/VENUS/IPTS-36063/shared/processed_data/jean</span>

# %% [markdown]
# # Normalization settings

# %%
o_norm.settings()
# Out:
# Label(value='What to take into account for normalization?')
# VBox(children=(Checkbox(value=True, description='Proton charge'), Checkbox(value=True, description='Shutter co…
# <hr>
# HBox(children=(Label(value='Distance source detector (m)', layout=Layout(width='200px')), FloatText(value=25.0…

# %% [markdown]
# # Select what you want to export

# %%
o_norm.what_to_export()
# Out:
# <span style='font-size: 16px; color:red'>Stack of images</span>
# VBox(children=(Checkbox(value=False, description='Export corrected stack of sample data', layout=Layout(width=…
# <span style='font-size: 16px; color:red'>Integrated images</span>
# VBox(children=(Checkbox(value=False, description='Export corrected integrated sample data', layout=Layout(widt…

# %% [markdown]
# # Launch the Normalization

# %%
o_norm.run_normalization_with_list_of_runs(preview=True)
# Out:
# Sample run numbers: ['/SNS/VENUS/IPTS-36063/shared/autoreduce/mcp/images/Run_8702', '/SNS/VENUS/IPTS-36063/shared/autoreduce/mcp/images/Run_8704']
# List of ob run numbers: ['/SNS/VENUS/IPTS-36063/shared/autoreduce/mcp/images/Run_8703']
# Loading ob# 8703 ...
# ob# 8703 loaded!
# ob_master_dict[_ob_run_number][MasterDictKeys.data].shape = (2628, 512, 512)
# ob_data_combined.shape = (2628, 512, 512)
# Loading sample# 8702 ...
# sample# 8702 loaded!
# sample_master_dict[_sample_run_number][MasterDictKeys.data].shape = (2628, 512, 512)
# Loading sample# 8704 ...
# sample# 8704 loaded!
# sample_master_dict[_sample_run_number][MasterDictKeys.data].shape = (2628, 512, 512)
# Normalization of run 8702
# Exported normalized tif images are in: /SNS/VENUS/IPTS-36063/shared/processed_data/jean/normalized_8702/stack!
# Normalization of run 8704
# Exported normalized tif images are in: /SNS/VENUS/IPTS-36063/shared/processed_data/jean/normalized_8704/stack!
# Normalization and export is done!
# <span style='color:blue'>Normalization completed</span>
# Log file: /SNS/VENUS/shared/logs/normalization_for_timepix.log
