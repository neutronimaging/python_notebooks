# %% [markdown]
# <!-- [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/normalization/normalization_tof/) -->
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # <font color='red'>Select Your IPTS</font>

# %%
from __code.normalization_tof.normalization_tof import NormalizationTof

from __code import system
system.System.select_working_dir(notebook='normalization', instrument="VENUS", ipts="IPTS-35423", instrument_to_exclude=["CG1D"])
from __code.__all import custom_style
custom_style.style()

NormalizationTof.legend()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(index=1, la…
# <hr style='height:2px'/>
# <h2>Legend</h2>
# <ul><li><b><font color='red'>Mandatory steps</font></b> must be performed to ensure proper data preparation and reconstruction.</li><li><b><font color='orange'>Optional but recommended steps</font></b> are not mandatory but should be performed to ensure proper data preparation and reconstruction.</li><li><b><font color='purple'>Optional steps</font></b> are not mandatory but highly recommended to improve the quality of your reconstruction.</li></ul>
# <hr style='height:2px'/>

# %% [markdown]
# # <font color='red'>Select detector type</font>

# %%
o_norm = NormalizationTof(working_dir=f"/SNS/{system.System.get_instrument_selected()}/IPTS-{system.System.get_ipts_selected()}", debug=False)
# Out:
# <span style='color:blue; font-size:16px'>Select detector type</span>
# Dropdown(index=1, layout=Layout(width='400px'), options=('tpx1 - old naming convention (until July 2025)', 'tp…

# %% [markdown]
# # <font color='red'>Select or browse list of sample data sets to normalize</font>

# %%
o_norm.select_sample_run_numbers()
# Out:
# VBox(children=(HTML(value="<b><font color='green'>List of sample run numbers (ex: 8702, 8704-8706)</font></b>"…
# <span style='font-size: 16px; color:red'>OR</span>
# VBox(children=(HTML(value="<b><font color='green'>Browse sample runs to normalize</b>"), VBox(children=(HBox(c…

# %% [markdown]
# #### Check sample inputs

# %%
o_norm.check_sample()
# Out:
# Sample run numbers selected:
# <span style='color:green'>/SNS/VENUS/IPTS-35423/shared/autoreduce/images/tpx1/raw/radiography/20251114_Smp8_resonance_5_200C_0_000AngsMin/20251114_Run_14611_Smp8_resonance_5_200C_0_000AngsMin_0</span> - OK
# DEBUGGING
# type(_run)= <class 'str'>
# _run = '/SNS/VENUS/IPTS-35423/shared/autoreduce/images/tpx1/raw/radiography/20251114_Smp8_resonance_5_200C_0_000AngsMin/20251114_Run_14611_Smp8_resonance_5_200C_0_000AngsMin_0'
# len(_run) = 167
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 o_norm.check_sample()
#
# File /gpfs/neutronsfs/instruments/VENUS/shared/software/git/python_notebooks_development/notebooks/__code/normalization_tof/normalization_tof.py:399, in NormalizationTof.check_sample(self)
#     396 print(f"{_run = }")
#     397 print(f"{len(_run) = }")
# --> 399 _is_spectra_file_found, spectra_file_name = NormalizationTof._is_spectra_file_found_and_list(_run)
#     400 if not _is_spectra_file_found:
#     401     self.spectra_file_found = False
#
# TypeError: NormalizationTof._is_spectra_file_found_and_list() takes 1 positional argument but 2 were given

# %% [markdown]
# # <font color='red'>Select list of open beam runs</font>
#
# The OB runs will be combined and used on each of the sample runs

# %%
o_norm.select_ob_run_numbers()

# %% [markdown]
# #### Check ob inputs

# %%
o_norm.check_ob()

# %% [markdown]
# <hr style="height: 2px" /><hr style="border-bottom: dotted 1px" />
# <font color='purple' size='5'>Preview open beams</font><font color='purple' size='3'> - OPTIONAL</font>

# %%
o_norm.preview_ob_runs()

# %% [markdown]
# <hr style="height: 2px" /><hr style="border-bottom: dotted 1px" />
# <font color='purple' size='5'>Select list of dark current runs</font><font color='purple' size='3'> - OPTIONAL</font>

# %%
o_norm.select_dc_run_numbers()

# %% [markdown]
# ### Check dc inputs

# %%
o_norm.check_dc()

# %% [markdown]
# <hr style="border-bottom: dotted 1px;" />
# <hr style="height: 2px" />
#
# # <font color='red'>Checking spectra file</font>

# %%
o_norm.checking_spectra_files()

# %% [markdown]
# # <font color='red'>Select Output Folder</font>

# %%
o_norm.select_output_folder()

# %% [markdown]
# # <font color='red'>Normalization settings</font>

# %% [markdown]
# #### step 1

# %%
o_norm.settings()

# %% [markdown]
# #### step2

# %%
o_norm.post_settings()

# %% [markdown]
# <hr style="height: 2px" /><hr style="border-bottom: dotted 1px" />
# <font color='purple' size='5'>Preview of container ROI imported</font><font color='purple' size='3'> - OPTIONAL</font>

# %%
o_norm.preview_roi_selection_container_imported()

# %% [markdown]
# <hr style="border-bottom: dotted 1px;" />
# <hr style="height: 2px" />
#
# # <font color='red'>Select what you want to export</font>

# %%
o_norm.what_to_export()

# %% [markdown]
# # <font color='red'>Launch the Normalization</font>

# %%
o_norm.run_normalization_with_list_of_runs(preview=True)
