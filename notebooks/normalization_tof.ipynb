# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/normalization/normalization_tof/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # <font color='red'>Select Your IPTS</font>

# %%
from __code.normalization_tof.normalization_tof import NormalizationTof

from __code import system
system.System.select_working_dir(notebook='normalization', instrument="VENUS", ipts="IPTS-35423", instrument_to_exclude=["CG1D","SNAP"])
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %% [markdown]
# # <font color='red'>Select detector type</font>

# %%
o_norm = NormalizationTof(working_dir=f"/SNS/VENUS/IPTS-{system.System.get_ipts_selected()}", debug=True)
# Out:
# <span style='color:blue; font-size:16px'>Select detector type</span>
# Dropdown(index=1, layout=Layout(width='400px'), options=('tpx1 - old naming convention (until July 2025)', 'tp…

# %% [markdown]
# # <font color='red'>Select or browse list of sample data sets to normalize</font>

# %%
o_norm.select_sample_run_numbers()
# Out:
# VBox(children=(HTML(value="<b><font color='green'>List of sample run numbers (ex: 8702, 8704-8706)</font></b>"…
# <span style='font-size: 16px; color:red'>OR</span>
# VBox(children=(HTML(value="<b><font color='green'>Browse sample runs to normalize</b>"), VBox(children=(HBox(c…

# %% [markdown]
# #### Check sample inputs

# %%
o_norm.check_sample()
# Out:
# Sample run numbers selected:
# <span style='color:green'>/SNS/VENUS/IPTS-35423/shared/autoreduce/images/tpx1/raw/radiography/20251113_9_CoConon__4_000C_0_700AngsMin/20251113_Run_14501_9_CoConon__4_000C_0_700AngsMin_0</span> - OK
#                         <h3>Information for run: 20251113_Run_14501_9_CoConon__4_000C_0_700AngsMin_0</h3>
#                     <table border="3px solid black" style="border-collapse:collapse;">
#                         <tr><th>Nbr TIFF</th><th>Images height</th><th>Images width</th><th>Data Type</th></tr>
#                         <tr><td>1468</td><td>512</td><td>512</td><td>float32</td></tr>
#                     </table>

# %% [markdown]
# # <font color='red'>Select list of open beam runs</font>
#
# The OB runs will be combined and used on each of the sample runs

# %%
o_norm.select_ob_run_numbers()
# Out:
# VBox(children=(HTML(value="<b><font color='green'>List of ob run numbers (ex: 8705, 8707)</font></b>"), Textar…
# <span style='font-size: 16px; color:red'>OR</span>
# VBox(children=(HTML(value="<b><font color='green'>Browse ob run number folders</b>"), VBox(children=(HBox(chil…

# %% [markdown]
# #### Check ob inputs

# %%
o_norm.check_ob()
# Out:
# OB run numbers selected:
# <span style='color:green'>/SNS/VENUS/IPTS-35423/shared/autoreduce/images/tpx1/ob/20251113_OB__5_000C_0_700AngsMin/20251113_Run_14490_OB__5_000C_0_700AngsMin_ob_0</span> - OK
#                         <h3>Information for run: 20251113_Run_14490_OB__5_000C_0_700AngsMin_ob_0</h3>
#                     <table border="3px solid black" style="border-collapse:collapse;">
#                         <tr><th>Nbr TIFF</th><th>Images height</th><th>Images width</th><th>Data Type</th></tr>
#                         <tr><td>1468</td><td>512</td><td>512</td><td>float32</td></tr>
#                     </table>

# %% [markdown]
# <hr style="height: 2px" /><hr style="border-bottom: dotted 1px" />
# <font color='purple' size='5'>Preview open beams</font><font color='purple' size='3'> - OPTIONAL</font>

# %%
# o_norm.preview_ob_runs()

# %% [markdown]
# <hr style="height: 2px" /><hr style="border-bottom: dotted 1px" />
# <font color='purple' size='5'>Select list of dark current runs</font><font color='purple' size='3'> - OPTIONAL</font>

# %%
# o_norm.select_dc_run_numbers()

# %% [markdown]
# ### Check dc inputs

# %%
# o_norm.check_dc()

# %% [markdown]
# <hr style="border-bottom: dotted 1px;" />
# <hr style="height: 2px" />
#
# # <font color='red'>Select Output Folder</font>

# %%
o_norm.select_output_folder()
# Out:
# Output folder selected:
# <span style='color:blue'>/SNS/VENUS/IPTS-35423/shared/processed_data/jean_test - DOES NOT EXIST and will be CREATED!</span>

# %% [markdown]
# # <font color='red'>Normalization settings</font>

# %% [markdown]
# #### step 1

# %%
o_norm.settings()
# Out:
# <span style='font-size: 16px; color:red'>Normalization pixel by pixel</span>
# Checkbox(value=True, description='Normalization of images pixel by pixel', disabled=True, layout=Layout(width=…
# <hr>
# <span style='font-size: 16px; color:red'>Normalization of full spectrum of ROI</span>
# <span style='font-size: 12px;'>If checked, normalization will be done as follows. After selecting a region of interest (ROI), for each image, the total counts of that region of the sample will be divided by the total counts of the same region of the OB. This will produce a profile of this normalization value for each image.</span>
# Checkbox(value=True, description='Work on full spectrum of ROI')
# <hr>
# <span style='font-size: 16px; color:red'>Remove container</span>
# Checkbox(value=True, description='Do you want to remove container signal?', layout=Layout(width='600px'))
# <hr>
# <span style='font-size: 16px; color:red'>What to take into account for the normalization</span>
# VBox(children=(Checkbox(value=True, description='Proton charge'), Checkbox(value=False, description='Correct c…
# <hr>
# <span style='font-size: 16px; color:red'>How to handle OB zeros - <i>May take much more time!</i></span>
# Checkbox(value=True, description='Ignore zeros in OB during normalization', disabled=True, layout=Layout(width…
# Checkbox(value=False, description='Replace zeros by local median', layout=Layout(width='500px'))
# HBox(children=(Label(value='Kernel size for local median (odd number):', layout=Layout(width='300')), BoundedI…
# HBox(children=(Label(value='Maximum number of iterations:', layout=Layout(width='300px')), BoundedIntText(valu…
# <hr>
# HBox(children=(Label(value='Distance source detector (m)', layout=Layout(width='200px')), FloatText(value=25.0…

# %% [markdown]
# #### step2

# %%
o_norm.post_settings()

# %% [markdown]
# # <font color='red'>Select what you want to export</font>

# %%
o_norm.what_to_export()

# %% [markdown]
# # <font color='red'>Launch the Normalization</font>

# %%
o_norm.run_normalization_with_list_of_runs(preview=True)
