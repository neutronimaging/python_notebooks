# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/tutorials/imaging-notebooks/normalization/normalization_tof/)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # <font color='red'>Select Your IPTS</font>

# %%
from __code.normalization_tof.normalization_tof import NormalizationTof

from __code import system
system.System.select_working_dir(notebook='normalization', instrument="VENUS", ipts="IPTS-35945", instrument_to_exclude=["CG1D","SNAP"])
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# Log file name: /SNS/VENUS/shared/log/j35_normalization_tof.log
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %% [markdown]
# # <font color='red'>Select detector type</font>

# %%
o_norm = NormalizationTof(working_dir=system.System.get_working_dir(), debug=False)
# Out:
# <span style='color:blue; font-size:16px'>Select detector type</span>
# Dropdown(index=1, layout=Layout(width='400px'), options=('tpx1 - old naming convention (until July 2025)', 'tp…

# %% [markdown]
# # <font color='red'>Select or browse list of sample data sets to normalize</font>

# %%
o_norm.select_sample_run_numbers()
# Out:
# VBox(children=(HTML(value="<b><font color='green'>List of sample run numbers (ex: 8702, 8704-8706)</font></b>"…
# <span style='font-size: 16px; color:red'>OR</span>
# VBox(children=(HTML(value="<b><font color='green'>Browse sample runs to normalize</b>"), VBox(children=(HBox(c…

# %% [markdown]
# #### Check sample inputs

# %%
o_norm.check_sample()
# Out:
# Sample run numbers selected:
# <span style='color:green'>/SNS/VENUS/IPTS-35945/shared/autoreduce/mcp/images/Run_9232</span> - OK

# %% [markdown]
# # <font color='red'>Select list of open beam runs</font>
#
# The OB runs will be combined and used on each of the sample runs

# %%
o_norm.select_ob_run_numbers()
# Out:
# VBox(children=(HTML(value="<b><font color='green'>List of ob run numbers (ex: 8705, 8707)</font></b>"), Textar…
# <span style='font-size: 16px; color:red'>OR</span>
# VBox(children=(HTML(value="<b><font color='green'>Browse ob run number folders</b>"), VBox(children=(HBox(chil…

# %% [markdown]
# #### Check ob inputs

# %%
o_norm.check_ob()
# Out:
# OB run numbers selected:
# <span style='color:green'>/SNS/VENUS/IPTS-35945/shared/autoreduce/mcp/images/Run_9234</span> - OK

# %% [markdown]
# <hr style="height: 2px" /><hr style="border-bottom: dotted 1px" />
# <font color='purple' size='5'>Preview open beams</font><font color='purple' size='3'> - OPTIONAL</font>

# %%
o_norm.preview_ob_runs()

# %% [markdown]
# <hr style="border-bottom: dotted 1px;" />
# <hr style="height: 2px" />
#
# # <font color='red'>Select Output Folder</font>

# %%
o_norm.select_output_folder()
# Out:
# VBox(children=(HTML(value="<b><font color='green'>Select output folder</b>"), VBox(children=(HBox(children=(HB…

# %% [markdown]
# # <font color='red'>Normalization settings</font>

# %%
o_norm.settings()
# Out:
# Label(value='What to take into account for normalization?')
# VBox(children=(Checkbox(value=True, description='Proton charge'), Checkbox(value=True, description='Shutter co…
# <hr>
# HBox(children=(Label(value='Distance source detector (m)', layout=Layout(width='200px')), FloatText(value=25.0…

# %% [markdown]
# # <font color='red'>Select what you want to export</font>

# %%
o_norm.what_to_export()
# Out:
# <span style='font-size: 16px; color:red'>Stack of images</span>
# VBox(children=(Checkbox(value=False, description='Export corrected stack of sample data', layout=Layout(width=…
# <span style='font-size: 16px; color:red'>Integrated images</span>
# VBox(children=(Checkbox(value=False, description='Export corrected integrated sample data', layout=Layout(widt…

# %% [markdown]
# # <font color='red'>Launch the Normalization</font>

# %%
o_norm.run_normalization_with_list_of_runs(preview=True)
# Out:
# Sample run numbers: ['Run_9232']
# List of ob run numbers: ['Run_9234']
# Loading ob# Run_9234 ...
# ob# Run_9234 loaded!
# ob_master_dict[_ob_run_number][MasterDictKeys.data].shape = (2786, 512, 512)
# ob_data_combined.shape = (2786, 512, 512)
# Correcting chips alignment ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 o_norm.run_normalization_with_list_of_runs(preview=True)
#
# File /gpfs/neutronsfs/instruments/VENUS/shared/software/git/python_notebooks_development/notebooks/__code/normalization_tof/normalization_tof.py:714, in NormalizationTof.run_normalization_with_list_of_runs(self, preview)
#     711     else:
#     712         correct_chips_alignment_config = None
# --> 714 normalization_with_list_of_full_path(sample_dict=sample_dict,
#     715                                     ob_dict=ob_dict,
#     716                                     output_folder=output_folder,
#     717                                     proton_charge_flag=self.proton_charge_flag.value,
#     718                                     shutter_counts_flag=self.shutter_counts_flag.value,
#     719                                     replace_ob_zeros_by_nan_flag=self.replace_ob_zeros_by_nan_flag.value,
#     720                                     correct_chips_alignment_flag=self.correct_chips_alignment_flag.value,
#     721                                     correct_chips_alignment_config=correct_chips_alignment_config,
#     722                                     verbose=True,
#     723                                     instrument=self.instrument,
#     724                                     detector_delay_us=detector_delay_us,
#     725                                     preview=preview,
#     726                                     distance_source_detector_m=self.distance_source_detector.value,
#     727                                     export_mode=export_mode)
#     728 display(HTML("<span style='color:blue'>Normalization completed</span>"))
#     729 display(HTML(f"Log file: /SNS/VENUS/shared/logs/normalization_for_timepix.log"))
#
# File /gpfs/neutronsfs/instruments/VENUS/shared/software/git/python_notebooks_development/notebooks/__code/normalization_tof/normalization_for_timepix1_timepix3.py:245, in normalization_with_list_of_full_path(sample_dict, ob_dict, output_folder, verbose, proton_charge_flag, shutter_counts_flag, replace_ob_zeros_by_nan_flag, output_tif, instrument, detector_delay_us, preview, distance_source_detector_m, correct_chips_alignment_flag, correct_chips_alignment_config, export_mode)
#     243 if verbose:
#     244     display(HTML("Correcting chips alignment ..."))
# --> 245     ob_data_combined = correct_chips_alignment(ob_data_combined, correct_chips_alignment_config)
#     246     logging.info(f"Chips alignment corrected!")
#     247     if verbose:
#
# File /gpfs/neutronsfs/instruments/VENUS/shared/software/git/python_notebooks_development/notebooks/__code/normalization_tof/normalization_for_timepix1_timepix3.py:126, in correct_chips_alignment(data, config)
#     122     o_corrector = TimepixGeometryCorrection(raw_image=_data,
#     123                                             config=config)
#     125     data_corrected = o_corrector.correct()
# --> 126     data[_index] = data_corrected
#     128 logging.info(f"\t{np.shape(data_corrected) = }")
#     129 logging.info(f"Chips alignment corrected!")
#
# ValueError: could not broadcast input array from shape (514,513) into shape (512,512)
