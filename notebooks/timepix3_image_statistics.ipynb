# %% [markdown]
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select your IPTS

# %%
from __code import system
from __code.timepix3_image_statistics.main import Timepix3ImageStatistics

system.System.select_working_dir(facility='SNS', ipts="IPTS-34969", instrument='VENUS', instrument_to_exclude=["SNAP", "MARS"])
from __code.__all import custom_style
custom_style.style()

import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ...

# %% [markdown]
# # Select the tpx3 data file

# %%
o_tpx3 = Timepix3ImageStatistics(working_dir=system.System.get_working_dir(), debug=True)
o_tpx3.select_tpx3_folder()
# Out:
# ...
# <span style='color:green'>Folder /SNS/VENUS/IPTS-34969/images/mcp/images/Run_6211 does not contain .tif files. Using sub-folder /SNS/VENUS/IPTS-34969/images/mcp/images/Run_6211/tpx3 instead</span>
#             <h3>TPX3 Folder Information</h3>
#             <table border="3px solid black" style="border-collapse:collapse;">
#                 <tr><th><b>Property</b></th><th><b>Value</b></th></tr>
#                 <tr><td>Original folder name</td><td>/SNS/VENUS/IPTS-34969/images/mcp/images/Run_6211</td></tr>
#                 <tr><td>Sub-folder name</td><td>/SNS/VENUS/IPTS-34969/images/mcp/images/Run_6211/tpx3</td></tr>
#                 <tr><td>Base name</td><td>tpx3</td></tr>
#                 <tr><td>Path</td><td>/SNS/VENUS/IPTS-34969/images/mcp/images/Run_6211</td></tr>
#                 <tr><td>Size</td><td>0.25 MB</td></tr>
#                 <tr><td>Last modified</td><td>Wed Jan 29 11:00:48 2025</td></tr>
#                 <tr><td>Number of .tif files</td><td>1600</td></tr>
# ...

# %% [markdown]
# # Produce statistics

# %%
o_tpx3.produce_statistics()
