# %% [markdown]
# # Build UI and Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

from __code.ui_builder import UiBuilder
o_builder = UiBuilder(ui_name = 'ui_addie.ui')
o_builder = UiBuilder(ui_name = 'ui_addie_save_config.ui')

from __code.addie import Interface

# from __code.__all import custom_style
# custom_style.style()
# Out:
# pyuic5 /Volumes/my_book_thunderbolt_duo/git/IPTS/python_notebooks/ui/ui_addie.ui -o /Volumes/my_book_thunderbolt_duo/git/IPTS/python_notebooks/__code/ui_addie.py
# pyuic5 /Volumes/my_book_thunderbolt_duo/git/IPTS/python_notebooks/ui/ui_addie_save_config.ui -o /Volumes/my_book_thunderbolt_duo/git/IPTS/python_notebooks/__code/ui_addie_save_config.py

# %%
# %gui qt

# %% [markdown]
# # Launch UI

# %%
o_interface = Interface()
o_interface.show()
# Out:
# config_to_load
# {'h1': {0: {'visible': True, 'width': 388},
#         1: {'visible': False, 'width': 0},
#         2: {'visible': True, 'width': 990}},
#  'h2': {0: {'visible': True, 'width': 90},
#         1: {'visible': False, 'width': 0},
#         2: {'visible': False, 'width': 0},
#         3: {'visible': False, 'width': 0},
#         4: {'visible': False, 'width': 0},
#         5: {'visible': False, 'width': 0},
#         6: {'visible': False, 'width': 0},
#         7: {'visible': False, 'width': 0},
#         8: {'visible': False, 'width': 0},
#         9: {'visible': True, 'width': 90},
#         10: {'visible': True, 'width': 180},
#         11: {'visible': True, 'width': 90},
#         12: {'visible': True, 'width': 90},
#         13: {'visible': True, 'width': 270},
#         14: {'visible': True, 'width': 90},
#         15: {'visible': True, 'width': 90},
#         16: {'visible': True, 'width': 90}},
#  'h3': {0: {'visible': True, 'width': 90},
#         1: {'visible': False, 'width': 0},
#         2: {'visible': False, 'width': 0},
#         3: {'visible': False, 'width': 0},
#         4: {'visible': False, 'width': 0},
#         5: {'visible': False, 'width': 0},
#         6: {'visible': False, 'width': 0},
#         7: {'visible': False, 'width': 0},
#         8: {'visible': False, 'width': 0},
#         9: {'visible': False, 'width': 0},
#         10: {'visible': False, 'width': 0},
#         11: {'visible': False, 'width': 0},
#         12: {'visible': True, 'width': 90},
#         13: {'visible': True, 'width': 90},
#         14: {'visible': True, 'width': 90},
#         15: {'visible': True, 'width': 90},
#         16: {'visible': True, 'width': 90},
#         17: {'visible': True, 'width': 90},
#         18: {'visible': True, 'width': 90},
#         19: {'visible': True, 'width': 90},
#         20: {'visible': True, 'width': 90},
#         21: {'visible': True, 'width': 90},
#         22: {'visible': True, 'width': 90}}}
# --------------------
# tree_dict
# OrderedDict([('title',
#               {'children': None,
#                'h_index': {'h1': 0, 'h2': None, 'h3': None},
#                'name': 'Title',
#                'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x1264115e8>}),
#              ('sample',
#               {'children': OrderedDict([('sample_runs',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 1,
#                                                       'h3': None},
#                                           'name': 'Runs',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411708>}),
#                                         ('sample_background',
#                                          {'children': OrderedDict([('sample_background_runs',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 2},
#                                                                      'name': 'Runs',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411828>}),
#                                                                    ('sample_background_background',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 3},
#                                                                      'name': 'Background',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x1264118b8>})]),
#                                           'h_index': {'h1': None,
#                                                       'h2': 2,
#                                                       'h3': None},
#                                           'name': 'Background',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411798>}),
#                                         ('sample_material',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 3,
#                                                       'h3': None},
#                                           'name': 'Material',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411948>}),
#                                         ('sample_packing_fraction',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 4,
#                                                       'h3': None},
#                                           'name': 'Packing Fraction',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x1264119d8>}),
#                                         ('sample_geometry',
#                                          {'children': OrderedDict([('sample_geometry_shape',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 6},
#                                                                      'name': 'Shape',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411af8>}),
#                                                                    ('sample_geometry_radius',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 7},
#                                                                      'name': 'Radius',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411b88>}),
#                                                                    ('sample_geometry_Height',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 8},
#                                                                      'name': 'Height',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411c18>})]),
#                                           'h_index': {'h1': None,
#                                                       'h2': 5,
#                                                       'h3': None},
#                                           'name': 'Geometry',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411a68>}),
#                                         ('sample_absolute_correction',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 6,
#                                                       'h3': None},
#                                           'name': 'Abs. Correction',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411ca8>}),
#                                         ('sample_multi_scattering_correction',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 7,
#                                                       'h3': None},
#                                           'name': 'Multi Scattering Correction',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411d38>}),
#                                         ('sample_inelastic_correction',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 8,
#                                                       'h3': None},
#                                           'name': 'Inelastic Correction',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411dc8>})]),
#                'h_index': {'h1': 1, 'h2': None, 'h3': None},
#                'name': 'Sample',
#                'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411678>}),
#              ('vanadium',
#               {'children': OrderedDict([('vanadium_runs',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 9,
#                                                       'h3': None},
#                                           'name': 'Runs',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411ee8>}),
#                                         ('vanadium_background',
#                                          {'children': OrderedDict([('vanadium_background_runs',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 14},
#                                                                      'name': 'Runs',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126414048>}),
#                                                                    ('vanadium_background_background',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 15},
#                                                                      'name': 'Background',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x1264140d8>})]),
#                                           'h_index': {'h1': None,
#                                                       'h2': 10,
#                                                       'h3': None},
#                                           'name': 'Background',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411f78>}),
#                                         ('vanadium_material',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 11,
#                                                       'h3': None},
#                                           'name': 'Materials',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126414168>}),
#                                         ('vanadium_packing_fraction',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 12,
#                                                       'h3': None},
#                                           'name': 'Packing Fraction',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x1264141f8>}),
#                                         ('vanadium_geometry',
#                                          {'children': OrderedDict([('vanadium_geometry_shape',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 18},
#                                                                      'name': 'Shape',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126414318>}),
#                                                                    ('vanadium_geometry_radius',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 19},
#                                                                      'name': 'Radius',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x1264143a8>}),
#                                                                    ('vanadium_geometry_Height',
#                                                                     {'children': None,
#                                                                      'h_index': {'h1': None,
#                                                                                  'h2': None,
#                                                                                  'h3': 20},
#                                                                      'name': 'Height',
#                                                                      'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126414438>})]),
#                                           'h_index': {'h1': None,
#                                                       'h2': 13,
#                                                       'h3': None},
#                                           'name': 'Geometry',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126414288>}),
#                                         ('vanadium_absolute_correction',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 14,
#                                                       'h3': None},
#                                           'name': 'Abs. Correction',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x1264144c8>}),
#                                         ('vanadium_multi_scattering_correction',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 15,
#                                                       'h3': None},
#                                           'name': 'Multi Scattering Correction',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126414558>}),
#                                         ('vanadium_inelastic_correction',
#                                          {'children': None,
#                                           'h_index': {'h1': None,
#                                                       'h2': 16,
#                                                       'h3': None},
#                                           'name': 'Inelastic Correction',
#                                           'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x1264145e8>})]),
#                'h_index': {'h1': 2, 'h2': None, 'h3': None},
#                'name': 'Vanadium',
#                'ui': <PyQt5.QtWidgets.QTreeWidgetItem object at 0x126411e58>})])
