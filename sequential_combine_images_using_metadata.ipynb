# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.pages.ornl.gov/en/tutorial/notebooks/sequential_combine_images_using_metadata)
#
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Select Your IPTS

# %%
from __code.sequential_combine_images_using_metadata import SequentialCombineImagesUsingMetadata
from __code import system
system.System.select_working_dir()
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ** Using Debugging Mode! **
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %% [markdown]
# # Select Folder containing all images to merge

# %%
o_merge = SequentialCombineImagesUsingMetadata(working_dir=system.System.get_working_dir())
o_merge.select_folder()
# Out:
# VBox(children=(Label(value='select folder of images to combine', layout=Layout(width='250px')), VBox(children=…
# <span style="font-size: 20px; color:blue">You selected folder: /Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019</span>

# %% [markdown]
# # Select Metadata to match

# %% [markdown]
# Only sequential runs having the **same metadata you are going to select** will be combined

# %%
o_merge.display_metadata_list()
# Out:
# HBox(children=(Label(value='Select Metadata:', layout=Layout(width='10%')), SelectMultiple(index=(48, 52), lay…

# %% [markdown]
# # Merging Method

# %%
o_merge.how_to_combine()
# Out:
# VBox(children=(HBox(children=(Label(value='Arithmetic Mean', layout=Layout(width='20%')), Image(value=b'GIF89a…

# %% [markdown]
# # Create merging list - for checking purpose

# %%
o_merge.create_merging_list()
# Out:
# HBox(children=(Label(value='Creating Merging List:', layout=Layout(width='20%')), IntProgress(value=1, layout=…
# OrderedDict([('position0', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_dummy_scan_0001_0080.tiff'], 'dict_metadata': {}}), ('position1', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0087.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position2', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0088.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position3', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0089.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position4', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0090.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position5', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0091.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position6', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0092.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position7', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0093.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position8', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0094.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position9', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0095.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position10', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0096.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-69.991816', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position11', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0097.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-11.032022', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position12', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0098.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-11.032022', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position13', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0099.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-11.032022', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position14', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0100.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-11.032022', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position15', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samples_2_3_10_0055_0101.tiff'], 'dict_metadata': {65040: 'MotLiftTable.RBV:-11.032022', 65044: 'MotLongAxis.RBV:330.000000'}}), ('position16', {'list_of_files': ['/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_samp ...

# %%
_file = '/Volumes/my_book_thunderbolt_duo/IPTS/IPTS-21632-Ed-Jeff-Katie/Nov18_2019/20191118_dummy_scan_0001_0080.tiff'
import os
os.path.exists(_file)
# Out:
# True

# %%
from PIL import Image

# %%
image = Image.open(_file)
metadata = image.tag_v2
image.close()

# %%
metadata.

# %% [markdown]
# # Select Output Folder

# %%
o_merge.select_output_folder()
# Out:
# VBox(children=(Label(value='select where to create the combined image ...', layout=Layout(width='250px')), VBo…

# %%
o_merge.define_output_filename()

# %% [markdown]
# # Merging

# %%
o_merge.merging()
